# %%
# !pip install --upgrade gtfs-realtime-bindings
# Out:
# Collecting gtfs-realtime-bindings
#   Downloading gtfs_realtime_bindings-2.0.0-py3-none-any.whl.metadata (650 bytes)
# Collecting protobuf (from gtfs-realtime-bindings)
#   Downloading protobuf-6.33.2-cp39-abi3-macosx_10_9_universal2.whl.metadata (593 bytes)
# Downloading gtfs_realtime_bindings-2.0.0-py3-none-any.whl (5.3 kB)
# Downloading protobuf-6.33.2-cp39-abi3-macosx_10_9_universal2.whl (427 kB)
# Installing collected packages: protobuf, gtfs-realtime-bindings
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [gtfs-realtime-bindings]
# Successfully installed gtfs-realtime-bindings-2.0.0 protobuf-6.33.2

# %%
from google.transit import gtfs_realtime_pb2
from datetime import datetime
import requests

# %%
rt_url = 'http://api.bart.gov/gtfsrt/tripupdate.aspx'

# %%
feed = gtfs_realtime_pb2.FeedMessage()
response = requests.get(rt_url)
feed.ParseFromString(response.content)

for i,e in enumerate(feed.entity):
    print(i)
    print(e)
    print('')
# Out:
# 0
# id: "1771660"
# trip_update {
#   trip {
#     trip_id: "1771660"
#     schedule_relationship: SCHEDULED
#   }
#   stop_time_update {
#     arrival {
#       delay: 69
#       time: 1765932279
#       uncertainty: 30
#     }
#     departure {
#       delay: 69
#       time: 1765932297
#       uncertainty: 30
#     }
#     stop_id: "S20-2"
#   }
#   stop_time_update {
#     arrival {
#       delay: 34
#       time: 1765932619
#       uncertainty: 30
#     }
#     departure {
#       delay: 34
#       time: 1765932637
#       uncertainty: 30
#     }
#     stop_id: "A90-2"
#   }
#   stop_time_update {
#     arrival {
#       delay: 0
#       time: 1765932839
#       uncertainty: 30
#     }
#     departure {
#       delay: 0
#       time: 1765932857
#       uncertainty: 30
#     }
#     stop_id: "A80-2"
#   }
#   stop_time_update {
#     arrival {
#       delay: 0
#       time: 1765933143
#       uncertainty: 30
#     }
#     departure {
#       delay: 0
#       time: 1765933161
#       uncertainty: 30
#     }
#     stop_id: "A70-2"
#   }
#   stop_time_update {
#     arrival {
#       delay: 0
#       time: 1765933384
#       uncertainty: 30
#     }
#     departure {
#       delay: 0
#       time: 1765933402
#       uncertainty: 30
#     }
#     stop_id: "A60-2"
#   }
#   stop_time_update {
#     arrival {
#       delay: 0
#       time: 1765933625
#       uncertainty: 30
#     }
#     departure {
#       delay: 0
#       time: 1765933643
#       uncertainty: 30
#     }
#     stop_id: "A50-2"
#   }
#   stop_time_update {
#     arrival {
#       delay: 0
#       time: 1765933854
#       uncertainty: 30
#     }
#     departure {
#       delay: 0
#       time: 1765933872
#       uncertainty: 30
#     }
#     stop_id: "A40-2"
#   }
#   stop_time_update {
#     arrival {
#       delay: 0
#       time: 1765934107
#       uncertainty: 30
#     }
#     departure {
#       delay: 0
#       time: 1765934125
#       uncertainty: 30
#     }
#     stop_id: "A30-2"
#   }
#   stop_time_update {
#     arrival {
#       delay: 0
#       time: 1765934306
#       uncertainty: 30
#     }
#     departure {
#       delay: 0
#       time: 1765934324
#       uncertainty: 30
#     }
#     stop_id: "A20-2"
#   }
#   stop_time_update {
#     arrival {
#       delay: 0
#       time: 1765934575
#       uncertainty: 30
#     }
#     departure {
#       delay: 0
#       time: 1765934593
#       uncertainty: 30
#     }
#     stop_id: "A10-2"
#   }
#   stop_time_update {
#     arrival {
#       delay: 0
#       time: 1765934893
#       uncertainty: 30
#     }
#     departure {
#       delay: 0
#       time: 1765934923
#       uncertainty: 30
#     }
#     stop_id: "M10-1"
#   }
#   stop_time_update {
#     arrival {
#       delay: 0
#       time: 1765935307
#       uncertainty: 30
#     }
#     departure {
#       delay: 0
#       time: 1765935343
#       uncertainty: 30
#     }
#     stop_id: "M16-1"
#   }
#   stop_time_update {
#     arrival {
#       delay: 0
#       time: 1765935409
#       uncertainty: 30
#     }
#     departure {
#       delay: 0
#       time: 1765935439
#       uncertainty: 30
#     }
#     stop_id: "M20-1"
#   }
#   stop_time_update {
#     arrival {
#       delay: 0
#       time: 1765935511
#       uncertainty: 30
#     }
#     departure {
#       delay: 0
#       time: 1765935541
#       uncertainty: 30
#     }
#     stop_id: "M30-1"
#   }
#   stop_time_update {
#     arrival {
#       delay: 0
#       time: 1765935613
#       uncertainty: 30
#     }
#     departure {
#       delay: 0
#       time: 1765935637
#       uncertainty: 30
#     }
#     stop_id: "M40-1"
#   }
#   stop_time_update {
#     arrival {
#       delay: 0
#       time: 1765935757
#       uncertainty: 30
#     }
#     departure {
#       delay: 0
#       time: 1765935775
#       uncertainty: 30
#     }
#     stop_id: "M50-1"
#   }
#   stop_time_update {
#     arrival {
#       delay: 0
#       time: 1765935877
#       uncertainty: 30
#     }
#     departure {
#       delay: 0
#       time: 1765935895
#       uncertainty: 30
#     }
#     stop_id: "M60-1"
#   }
#   stop_time_update {
#     arrival {
#       delay: 0
#       time: 1765936045
#       uncertainty: 30
#     }
#     departure {
#       delay: 0
#       time: 1765936063
#       uncertainty: 30
#     }
#     stop_id: "M70-1"
#   }
#   stop_time_update {
#     arrival {
#       delay: 0
#       time: 1765936183
#       uncertainty: 30
#     }
#     departure {
#       delay: 0
#       time: 1765936201
#       uncertainty: 30
#     }
#     stop_id: "M80-1"
#   }
#   vehicle {
#     label: "3-door"
#   }
# }
#
#
# 1
# id: "1771661"
# trip_update {
#   trip {
#     trip_id: "1771661"
#     schedule_relationship: SCHEDULED
#   }
#   stop_time_update {
#     arrival {
#       delay: 0
#       time: 1765931755
#       uncertainty: 30
#     }
#     departure {
#       delay: 0
#       time: 1765932725
#       uncertainty: 30
#     }
#     stop_id: "S50-1"
#   }
#   stop_time_update {
#     arrival {
#       delay: 0
#       time: 1765932953
#       uncertainty: 30
#     }
#     departure {
#       delay: 0
#       time: 1765932971
#       uncertainty: 30
#     }
#     stop_id: "S40-2"
#   }
#   stop_time_update {
#     arrival {
#       delay: 0
#       time: 1765933410
#       uncertainty: 30
#     }
#     departure {
#       delay: 0
#       time: 1765933428
#       uncertainty: 30
#     }
#     stop_id: "S20-2"
#   }
#   stop_time_update {
#     arrival {
#       delay: 0
#       time: 1765933786
#       uncertainty: 30
#     }
#     departure {
#       delay: 0
#       time: 1765933804
#       uncertainty: 30
#     }
#     stop_id: "A90-2"
#   }
#   stop_time_update {
#     arrival {
#       delay: 0
#       time: 1765934039
#       uncertainty: 30
#     }
#     departure {
#       delay: 0
#       time: 1765934057
#       uncertainty: 30
#     }
#     stop_id: "A80-2"
#   }
#   stop_time_update {
#     arrival {
#       delay: 0
#       time: 1765934343
#       uncertainty: 30
#     }
#     departure {
#       delay: 0
#       time: 1765934361
#       uncertainty: 30
#     }
#     stop_id: "A70-2"
#   }
#   stop_time_update {
#     arrival {
#       delay: 0
#       time: 1765934584
#       uncertainty: 30
#     }
#     departure {
#       delay: 0
#       time: 1765934602
#       uncertainty: 30
#     }
#     stop_id: "A60-2"
#   }
#   stop_time_update {
#     arrival {
#       delay: 0
#       time: 1765934825
#       uncertainty: 30
#     }
#     departure {
#       delay: 0
#       time: 1765934843
#       uncertainty: 30
#     }
#     stop_id: "A50-2"
#   }
#   stop_time_update {
#     arrival {
#       delay: 0
#       time: 1765935054
#       uncertainty: 30
#     }
#     departure {
#       delay: 0
#       time: 1765935072
#       uncertainty: 30
#     }
#     stop_id: "A40-2"
#   }
#   stop_time_update {
#     arrival {
#       delay: 0
#       time: 1765935307
#       uncertainty: 30
#     }
#     departure {
#       delay: 0
#       time: 1765935325
#       uncertainty: 30
#     }
#     stop_id: "A30-2"
#   }
#   stop_time_update {
#     arrival {
#       delay: 0
#       time: 1765935506
#       uncertainty: 30
#     }
#     departure {
#       delay: 0
#       time: 1765935524
#       uncertainty: 30
#     }
#     stop_id: "A20-2"
#   }
#   stop_time_update {
#     arrival {
#       delay: 0
#       time: 1765935775
#       uncertainty: 30
#     }
#     departure {
#       delay: 0
#       time: 1765935793
#       uncertainty: 30
#     }
#     stop_id: "A10-2"
#   }
#   stop_time_update {
#     arrival {
#       delay: 0
#       time: 1765936093
#       uncertainty: 30
#     }
#     departure {
#       delay: 0
#       time: 1765936123
#       uncertainty: 30
#     }
#     stop_id: "M10-1"
#   }
#   stop_time_update {
#     arrival {
#       delay: 0
#       time: 1765936507
#       uncertainty: 30
#     }
#     departure {
#       delay: 0
#       time: 1765936543
#       uncertainty: 30
#     }
#     stop_id: "M16-1"
#   }
#   stop_time_update {
#     arrival {
#       delay: 0
#       time: 1765936609
#       uncertainty: 30
#     }
#     departure {
#       delay: 0
#       time: 1765936639
#       uncertainty: 30
#     }
#     stop_id: "M20-1"
#   }
#   stop_time_update {
#     arrival {
#       delay: 0
#       time: 1765936711
#       uncertainty: 30
#     }
#     departure {
#       delay: 0
#       time: 1765936741
#       uncertainty: 30
#     }
#     stop_id: "M30-1"
#   }
#   stop_time_update {
#     arrival {
#       delay: 0
#       time: 1765936813
#       uncertainty: 30
#     }
#     departure {
#       delay: 0
#       time: 1765936837
#       uncertainty: 30
#     }
#     stop_id: "M40-1"
#   }
#   stop_time_update {
#     arrival {
#       delay: 0
#       time: 1765936957
#       uncertainty: 30
#     }
#     departure {
#       delay: 0
#       time: 1765936975
#       uncertainty: 30
#     }
#     stop_id: "M50-1"
#   }
#   stop_time_update {
#     arrival {
#       delay: 0
#       time: 1765937077
#       uncertainty: 30
#     }
#     departure {
#       delay: 0
#       time: 1765937095
#       uncertainty: 30
#     }
#     stop_id: "M60-1"
#   }
#   stop_time_update {
#     arrival {
#       delay: 0
#       time: 1765937245
#       uncertainty: 30
#     }
#     departure {
#       delay: 0
#       time: 1765937263
#       uncertainty: 30
#     }
#     stop_id: "M70-1"
#   }
#   stop_time_update {
#     arrival {
#       delay: 0
#       time: 1765937383
#       uncertainty: 30
#     }
#     departure {
#       delay: 0
#       time: 1765937401
#       uncertainty: 30
#     }
#     stop_id: "M80-1"
#   }
#   vehicle {
#     label: "3-door"
#   }
# }
#
#
# 2
# id: "1771607"
# trip_update {
#   trip {
#     trip_id: "1771607"
#     schedule_relationship: SCHEDULED
#   }
#   stop_time_update {
#     arrival {
#       delay: 43
#       time: 1765932179
#       uncertainty: 30
#     }
#     departure {
#       delay: 43
#       time: 1765932197
#       uncertainty: 30
#     }
#     stop_id: "S20-1"
#   }
#   stop_time_update {
#     arrival {
#       delay: 0
#       time: 1765932598
#       uncertainty: 30
#     }
#     departure {
#       delay: 0
#       time: 1765932616
#       uncertainty: 30
#     }
#     stop_id: "S40-1"
#   }
#   vehicle {
#     label: "3-door"
#   }
# }
#
#
# 3
# id: "1771662"
# trip_update {
#   trip {
#     trip_id: "1771662"
#     schedule_relationship: SCHEDULED
#   }
#   stop_time_update {
#     arrival {
#       delay: 0
#       time: 1765932880
#       uncertainty: 30
#     }
#     departure {
#       delay: 0
#       time: 1765933925
#       uncertainty: 30
#     }
#     stop_id: "S50-1"
#   }
#   stop_time_update {
#     arrival {
#       delay: 0
#       time: 1765934153
#       uncertainty: 30
#     }
#     departure {
#       delay: 0
#       time: 1765934171
#       uncertainty: 30
#     }
#     stop_id: "S40-2"
#   }
#   stop_time_update {
#     arrival {
#       delay: 0
#       time: 1765934610
#       uncertainty: 30
#     }
#     departure {
#       delay: 0
#       time: 1765934628
#       uncertainty: 30
#     }
#     stop_id: "S20-2"
#   }
#   stop_time_update {
#     arrival {
#       delay: 0
#       time: 1765934986
#       uncertainty: 30
#     }
#     departure {
#       delay: 0
#       time: 1765935004
#       uncertainty: 30
#     }
#     stop_id: "A90-2"
#   }
#   stop_time_update {
#     arrival {
#       delay: 0
#       time: 1765935239
#       uncertainty: 30
#     }
#     departure {
#       delay: 0
#       time: 1765935257
#       uncertainty: 30
#     }
#     stop_id: "A80-2"
#   }
#   stop_time_update {
#     arrival {
#       delay: 0
#       time: 1765935543
#       uncertainty: 30
#     }
#     departure {
#       delay: 0
#       time: 1765935561
#       uncertainty: 30
#     }
#     stop_id: "A70-2"
#   }
#   stop_time_update {
#     arrival {
#       delay: 0
#       time: 1765935784
#       uncertainty: 30
#     }
#     departure {
#       delay: 0
#       time: 1765935802
#       uncertainty: 30
#     }
#     stop_id: "A60-2"
#   }
#   stop_time_update {
#     arrival {
#       delay: 0
#       time: 1765936025
#       uncertainty: 30
#     }
#     departure {
#       delay: 0
#       time: 1765936043
#       uncertainty: 30
#     }
#     stop_id: "A50-2"
#   }
#   stop_time_update {
#     arrival {
#       delay: 0
#       time: 1765936254
#       uncertainty: 30
#     }
#     departure {
#       delay: 0
#       time: 1765936272
#       uncertainty: 30
#     }
#     stop_id: "A40-2"
#   }
#   stop_time_update {
#     arrival {
#       delay: 0
#       time: 1765936507
#       uncertainty: 30
#     }
#     departure {
#       delay: 0
#       time: 1765936525
#       uncertainty: 30
#     }
#     stop_id: "A30-2"
#   }
#   stop_time_update {
#     arrival {
#       delay: 0
#       time: 1765936706
#       uncertainty: 30
#     }
#     departure {
#       delay: 0
#       time: 1765936724
#       uncertainty: 30
#     }
#     stop_id: "A20-2"
#   }
#   stop_time_update {
#     arrival {
#       delay: 0
#       time: 1765936975
#       uncertainty: 30
#     }
#     departure {
#       delay: 0
#       time: 1765936993
#       uncertainty: 30
#     }
#     stop_id: "A10-2"
#   }
#   stop_time_update {
#     arrival {
#       delay: 0
#       time: 1765937293
#       uncertainty: 30
#     }
#     departure {
#       delay: 0
#       time: 1765937323
#       uncertainty: 30
#     }
#     stop_id: "M10-1"
#   }
#   stop_time_update {
#     arrival {
#       delay: 0
#       time: 1765937707
#       uncertainty: 30
#     }
#     departure {
#       delay: 0
#       time: 1765937743
#       uncertainty: 30
#     }
#     stop_id: "M16-1"
#   }
#   stop_time_update {
#     arrival {
#       delay: 0
#       time: 1765937809
#       uncertainty: 30
#     }
#     departure {
#       delay: 0
#       time: 1765937839
#       uncertainty: 30
#     }
#     stop_id: "M20-1"
#   }
#   stop_time_update {
#     arrival {
#       delay: 0
#       time: 1765937911
#       uncertainty: 30
#     }
#     departure {
#       delay: 0
#       time: 1765937941
#       uncertainty: 30
#     }
#     stop_id: "M30-1"
#   }
#   stop_time_update {
#     arrival {
#       delay: 0
#       time: 1765938013
#       uncertainty: 30
#     }
#     departure {
#       delay: 0
#       time: 1765938037
#       uncertainty: 30
#     }
#     stop_id: "M40-1"
#   }
#   stop_time_update {
#     arrival {
#       delay: 0
#       time: 1765938157
#       uncertainty: 30
#     }
#     departure {
#       delay: 0
#       time: 1765938175
#       uncertainty: 30
#     }
#     stop_id: "M50-1"
#   }
#   stop_time_update {
#     arrival {
#       delay: 0
#       time: 1765938277
#       uncertainty: 30
#     }
#     departure {
#       delay: 0
#       time: 1765938295
#       uncertainty: 30
#     }
#     stop_id: "M60-1"
#   }
#   stop_time_update {
#     arrival {
#       delay: 0
#       time: 1765938445
#       uncertainty: 30
#     }
#     departure {
#       delay: 0
#       time: 1765938463
#       uncertainty: 30
#     }
#     stop_id: "M70-1"
#   }
#   stop_time_update {
#     arrival {
#       delay: 0
#       time: 1765938583
#       uncertainty: 30
#     }
#     departure {
#       delay: 0
#       time: 1765938601
#       uncertainty: 30
#     }
#     stop_id: "M80-1"
#   }
#   vehicle {
#     label: "3-door"
#   }
# }
#
#
# 4
# id: "1771608"
# trip_update {
#   trip {
#     trip_id: "1771608"
#     schedule_relationship: SCHEDULED
#   }
#   stop_time_update {
#     arrival {
#       delay: 59
#       time: 1765932180
#       uncertainty: 30
#     }
#     departure {
#       delay: 59
#       time: 1765932198
#       uncertainty: 30
#     }
#     stop_id: "A60-1"
#   }
#   stop_time_update {
#     arrival {
#       delay: 31
#       time: 1765932405
#       uncertainty: 30
#     }
#     departure {
#       delay: 31
#       time: 1765932423
#       uncertainty: 30
#     }
#     stop_id: "A70-1"
#   }
#   stop_time_update {
#     arrival {
#       delay: 34
#       time: 1765932732
#       uncertainty: 30
#     }
#     departure {
#       delay: 34
#       time: 1765932750
#       uncertainty: 30
#     }
#     stop_id: "A80-1"
#   }
#   stop_time_update {
#     arrival {
#       delay: 0
#       time: 1765932961
#       uncertainty: 30
#     }
#     departure {
#       delay: 0
#       time: 1765932979
#       uncertainty: 30
#     }
#     stop_id: "A90-1"
#   }
#   stop_time_update {
#     arrival {
#       delay: 0
#       time: 1765933337
#       uncertainty: 30
#     }
#     departure {
#       delay: 0
#       time: 1765933355
#       uncertainty: 30
#     }
#     stop_id: "S20-1"
#   }
#   stop_time_update {
#     arrival {
#       delay: 0
#       time: 1765933798
#       uncertainty: 30
#     }
#     departure {
#       delay: 0
#       time: 1765933816
#       uncertainty: 30
#     }
#     stop_id: "S40-1"
#   }
#   vehicle {
#     label: "3-door"
#   }
# }
#
#
# 5
# id: "1771609"
# trip_update {
#   trip {
#     trip_id: "1771609"
#     schedule_relationship: SCHEDULED
#   }
#   stop_time_update {
#     arrival {
#       delay: 111
#       time: 1765932248
#       uncertainty: 30
#     }
#     departure {
#       delay: 111
#       time: 1765932268
#       uncertainty: 30
#     }
#     stop_id: "A10-1"
#   }
#   stop_time_update {
#     arrival {
#       delay: 71
#       time: 1765932460
#       uncertainty: 30
#     }
#     departure {
#       delay: 71
#       time: 1765932478
#       uncertainty: 30
#     }
#     stop_id: "A20-1"
#   }
#   stop_time_update {
#     arrival {
#       delay: 65
#       time: 1765932646
#       uncertainty: 30
#     }
#     departure {
#       delay: 65
#       time: 1765932664
#       uncertainty: 30
#     }
#     stop_id: "A30-1"
#   }
#   stop_time_update {
#     arrival {
#       delay: 69
#       time: 1765932895
#       uncertainty: 30
#     }
#     departure {
#       delay: 69
#       time: 1765932913
#       uncertainty: 30
#     }
#     stop_id: "A40-1"
#   }
#   stop_time_update {
#     arrival {
#       delay: 70
#       time: 1765933123
#       uncertainty: 30
#     }
#     departure {
#       delay: 70
#       time: 1765933151
#       uncertainty: 30
#     }
#     stop_id: "A50-1"
#   }
#   stop_time_update {
#     arrival {
#       delay: 39
#       time: 1765933360
#       uncertainty: 30
#     }
#     departure {
#       delay: 39
#       time: 1765933378
#       uncertainty: 30
#     }
#     stop_id: "A60-1"
#   }
#   stop_time_update {
#     arrival {
#       delay: 40
#       time: 1765933615
#       uncertainty: 30
#     }
#     departure {
#       delay: 40
#       time: 1765933633
#       uncertainty: 30
#     }
#     stop_id: "A70-1"
#   }
#   stop_time_update {
#     arrival {
#       delay: 31
#       time: 1765933930
#       uncertainty: 30
#     }
#     departure {
#       delay: 31
#       time: 1765933948
#       uncertainty: 30
#     }
#     stop_id: "A80-1"
#   }
#   stop_time_update {
#     arrival {
#       delay: 0
#       time: 1765934161
#       uncertainty: 30
#     }
#     departure {
#       delay: 0
#       time: 1765934179
#       uncertainty: 30
#     }
#     stop_id: "A90-1"
#   }
#   stop_time_update {
#     arrival {
#       delay: 0
#       time: 1765934537
#       uncertainty: 30
#     }
#     departure {
#       delay: 0
#       time: 1765934555
#       uncertainty: 30
#     }
#     stop_id: "S20-1"
#   }
#   stop_time_update {
#     arrival {
#       delay: 0
#       time: 1765934998
#       uncertainty: 30
#     }
#     departure {
#       delay: 0
#       time: 1765935016
#       uncertainty: 30
#     }
#     stop_id: "S40-1"
#   }
#   vehicle {
#     label: "3-door"
#   }
# }
#
#
# 6
# id: "1771610"
# trip_update {
#   trip {
#     trip_id: "1771610"
#     schedule_relationship: SCHEDULED
#   }
#   stop_time_update {
#     arrival {
#       delay: 105
#       time: 1765932231
#       uncertainty: 30
#     }
#     departure {
#       delay: 105
#       time: 1765932254
#       uncertainty: 30
#     }
#     stop_id: "M50-2"
#   }
#   stop_time_update {
#     arrival {
#       delay: 98
#       time: 1765932369
#       uncertainty: 30
#     }
#     departure {
#       delay: 98
#       time: 1765932393
#       uncertainty: 30
#     }
#     stop_id: "M40-2"
#   }
#   stop_time_update {
#     arrival {
#       delay: 95
#       time: 1765932462
#       uncertainty: 30
#     }
#     departure {
#       delay: 95
#       time: 1765932492
#       uncertainty: 30
#     }
#     stop_id: "M30-2"
#   }
#   stop_time_update {
#     arrival {
#       delay: 94
#       time: 1765932557
#       uncertainty: 30
#     }
#     departure {
#       delay: 94
#       time: 1765932583
#       uncertainty: 30
#     }
#     stop_id: "M20-2"
#   }
#   stop_time_update {
#     arrival {
#       delay: 71
#       time: 1765932629
#       uncertainty: 30
#     }
#     departure {
#       delay: 71
#       time: 1765932661
#       uncertainty: 30
#     }
#     stop_id: "M16-2"
#   }
#   stop_time_update {
#     arrival {
#       delay: 64
#       time: 1765933054
#       uncertainty: 30
#     }
#     departure {
#       delay: 64
#       time: 1765933080
#       uncertainty: 30
#     }
#     stop_id: "M10-2"
#   }
#   stop_time_update {
#     arrival {
#       delay: 32
#       time: 1765933369
#       uncertainty: 30
#     }
#     departure {
#       delay: 32
#       time: 1765933389
#       uncertainty: 30
#     }
#     stop_id: "A10-1"
#   }
#   stop_time_update {
#     arrival {
#       delay: 0
#       time: 1765933590
#       uncertainty: 30
#     }
#     departure {
#       delay: 0
#       time: 1765933608
#       uncertainty: 30
#     }
#     stop_id: "A20-1"
#   }
#   stop_time_update {
#     arrival {
#       delay: 0
#       time: 1765933782
#       uncertainty: 30
#     }
#     departure {
#       delay: 0
#       time: 1765933800
#       uncertainty: 30
#     }
#     stop_id: "A30-1"
#   }
#   stop_time_update {
#     arrival {
#       delay: 0
#       time: 1765934027
#       uncertainty: 30
#     }
#     departure {
#       delay: 0
#       time: 1765934045
#       uncertainty: 30
#     }
#     stop_id: "A40-1"
#   }
#   stop_time_update {
#     arrival {
#       delay: 0
#       time: 1765934253
#       uncertainty: 30
#     }
#     departure {
#       delay: 0
#       time: 1765934289
#       uncertainty: 30
#     }
#     stop_id: "A50-1"
#   }
#   stop_time_update {
#     arrival {
#       delay: 0
#       time: 1765934522
#       uncertainty: 30
#     }
#     departure {
#       delay: 0
#       time: 1765934540
#       uncertainty: 30
#     }
#     stop_id: "A60-1"
#   }
#   stop_time_update {
#     arrival {
#       delay: 0
#       time: 1765934775
#       uncertainty: 30
#     }
#     departure {
#       delay: 0
#       time: 1765934793
#       uncertainty: 30
#     }
#     stop_id: "A70-1"
#   }
#   stop_time_update {
#     arrival {
#       delay: 0
#       time: 1765935099
#       uncertainty: 30
#     }
#     departure {
#       delay: 0
#       time: 1765935117
#       uncertainty: 30
#     }
#     stop_id: "A80-1"
#   }
#   stop_time_update {
#     arrival {
#       delay: 0
#       time: 1765935361
#       uncertainty: 30
#     }
#     departure {
#       delay: 0
#       time: 1765935379
#       uncertainty: 30
#     }
#     stop_id: "A90-1"
#   }
#   stop_time_update {
#     arrival {
#       delay: 0
#       time: 1765935737
#       uncertainty: 30
#     }
#     departure {
#       delay: 0
#       time: 1765935755
#       uncertainty: 30
#     }
#     stop_id: "S20-1"
#   }
#   stop_time_update {
#     arrival {
#       delay: 0
#       time: 1765936198
#       uncertainty: 30
#     }
#     departure {
#       delay: 0
#       time: 1765936216
#       uncertainty: 30
#     }
#     stop_id: "S40-1"
#   }
#   vehicle {
#     label: "3-door"
#   }
# }
#
#
# 7
# id: "1771611"
# trip_update {
#   trip {
#     trip_id: "1771611"
#     schedule_relationship: SCHEDULED
#   }
#   stop_time_update {
#     arrival {
#       delay: 0
#       time: 1765932463
#       uncertainty: 30
#     }
#     departure {
#       delay: 0
#       time: 1765932468
#       uncertainty: 30
#     }
#     stop_id: "M90-2"
#   }
#   stop_time_update {
#     arrival {
#       delay: 0
#       time: 1765932907
#       uncertainty: 30
#     }
#     departure {
#       delay: 0
#       time: 1765932925
#       uncertainty: 30
#     }
#     stop_id: "M80-2"
#   }
#   stop_time_update {
#     arrival {
#       delay: 0
#       time: 1765933045
#       uncertainty: 30
#     }
#     departure {
#       delay: 0
#       time: 1765933063
#       uncertainty: 30
#     }
#     stop_id: "M70-2"
#   }
#   stop_time_update {
#     arrival {
#       delay: 0
#       time: 1765933207
#       uncertainty: 30
#     }
#     departure {
#       delay: 0
#       time: 1765933225
#       uncertainty: 30
#     }
#     stop_id: "M60-2"
#   }
#   stop_time_update {
#     arrival {
#       delay: 0
#       time: 1765933327
#       uncertainty: 30
#     }
#     departure {
#       delay: 0
#       time: 1765933351
#       uncertainty: 30
#     }
#     stop_id: "M50-2"
#   }
#   stop_time_update {
#     arrival {
#       delay: 0
#       time: 1765933471
#       uncertainty: 30
#     }
#     departure {
#       delay: 0
#       time: 1765933495
#       uncertainty: 30
#     }
#     stop_id: "M40-2"
#   }
#   stop_time_update {
#     arrival {
#       delay: 0
#       time: 1765933567
#       uncertainty: 30
#     }
#     departure {
#       delay: 0
#       time: 1765933597
#       uncertainty: 30
#     }
#     stop_id: "M30-2"
#   }
#   stop_time_update {
#     arrival {
#       delay: 0
#       time: 1765933663
#       uncertainty: 30
#     }
#     departure {
#       delay: 0
#       time: 1765933693
#       uncertainty: 30
#     }
#     stop_id: "M20-2"
#   }
#   stop_time_update {
#     arrival {
#       delay: 0
#       time: 1765933759
#       uncertainty: 30
#     }
#     departure {
#       delay: 0
#       time: 1765933795
#       uncertainty: 30
#     }
#     stop_id: "M16-2"
#   }
#   stop_time_update {
#     arrival {
#       delay: 0
#       time: 1765934191
#       uncertainty: 30
#     }
#     departure {
#       delay: 0
#       time: 1765934221
#       uncertainty: 30
#     }
#     stop_id: "M10-2"
#   }
#   stop_time_update {
#     arrival {
#       delay: 0
#       time: 1765934537
#       uncertainty: 30
#     }
#     departure {
#       delay: 0
#       time: 1765934573
#       uncertainty: 30
#     }
#     stop_id: "A10-1"
#   }
#   stop_time_update {
#     arrival {
#       delay: 0
#       time: 1765934790
#       uncertainty: 30
#     }
#     departure {
#       delay: 0
#       time: 1765934808
#       uncertainty: 30
#     }
#     stop_id: "A20-1"
#   }
#   stop_time_update {
#     arrival {
#       delay: 0
#       time: 1765934982
#       uncertainty: 30
#     }
#     departure {
#       delay: 0
#       time: 1765935000
#       uncertainty: 30
#     }
#     stop_id: "A30-1"
#   }
#   stop_time_update {
#     arrival {
#       delay: 0
#       time: 1765935227
#       uncertainty: 30
#     }
#     departure {
#       delay: 0
#       time: 1765935245
#       uncertainty: 30
#     }
#     stop_id: "A40-1"
#   }
#   stop_time_update {
#     arrival {
#       delay: 0
#       time: 1765935453
#       uncertainty: 30
#     }
#     departure {
#       delay: 0
#       time: 1765935489
#       uncertainty: 30
#     }
#     stop_id: "A50-1"
#   }
#   stop_time_update {
#     arrival {
#       delay: 0
#       time: 1765935722
#       uncertainty: 30
#     }
#     departure {
#       delay: 0
#       time: 1765935740
#       uncertainty: 30
#     }
#     stop_id: "A60-1"
#   }
#   stop_time_update {
#     arrival {
#       delay: 0
#       time: 1765935975
#       uncertainty: 30
#     }
#     departure {
#       delay: 0
#       time: 1765935993
#       uncertainty: 30
#     }
#     stop_id: "A70-1"
#   }
#   stop_time_update {
#     arrival {
#       delay: 0
#       time: 1765936299
#       uncertainty: 30
#     }
#     departure {
#       delay: 0
#       time: 1765936317
#       uncertainty: 30
#     }
#     stop_id: "A80-1"
#   }
#   stop_time_update {
#     arrival {
#       delay: 0
#       time: 1765936561
#       uncertainty: 30
#     }
#     departure {
#       delay: 0
#       time: 1765936579
#       uncertainty: 30
#     }
#     stop_id: "A90-1"
#   }
#   stop_time_update {
#     arrival {
#       delay: 0
#       time: 1765936937
#       uncertainty: 30
#     }
#     departure {
#       delay: 0
#       time: 1765936955
#       uncertainty: 30
#     }
#     stop_id: "S20-1"
#   }
#   stop_time_update {
#     arrival {
#       delay: 0
#       time: 1765937398
#       uncertainty: 30
#     }
#     departure {
#       delay: 0
#       time: 1765937416
#       uncertainty: 30
#     }
#     stop_id: "S40-1"
#   }
#   vehicle {
#     label: "3-door"
#   }
# }
#
#
# 8
# id: "1771657"
# trip_update {
#   trip {
#     trip_id: "1771657"
#     schedule_relationship: SCHEDULED
#   }
#   stop_time_update {
#     arrival {
#       delay: 91
#       time: 1765932248
#       uncertainty: 30
#     }
#     departure {
#       delay: 91
#       time: 1765932266
#       uncertainty: 30
#     }
#     stop_id: "M50-1"
#   }
#   stop_time_update {
#     arrival {
#       delay: 95
#       time: 1765932371
#       uncertainty: 30
#     }
#     departure {
#       delay: 95
#       time: 1765932389
#       uncertainty: 30
#     }
#     stop_id: "M60-1"
#   }
#   stop_time_update {
#     arrival {
#       delay: 93
#       time: 1765932537
#       uncertainty: 30
#     }
#     departure {
#       delay: 93
#       time: 1765932555
#       uncertainty: 30
#     }
#     stop_id: "M70-1"
#   }
#   stop_time_update {
#     arrival {
#       delay: 64
#       time: 1765932647
#       uncertainty: 30
#     }
#     departure {
#       delay: 64
#       time: 1765932665
#       uncertainty: 30
#     }
#     stop_id: "M80-1"
#   }
#   vehicle {
#     label: "3-door"
#   }
# }
#
#
# 9
# id: "1771612"
# trip_update {
#   trip {
#     trip_id: "1771612"
#     schedule_relationship: SCHEDULED
#   }
#   stop_time_update {
#     arrival {
#       delay: 0
#       time: 1765933663
#       uncertainty: 30
#     }
#     departure {
#       delay: 0
#       time: 1765933668
#       uncertainty: 30
#     }
#     stop_id: "M90-2"
#   }
#   stop_time_update {
#     arrival {
#       delay: 0
#       time: 1765934107
#       uncertainty: 30
#     }
#     departure {
#       delay: 0
#       time: 1765934125
#       uncertainty: 30
#     }
#     stop_id: "M80-2"
#   }
#   stop_time_update {
#     arrival {
#       delay: 0
#       time: 1765934245
#       uncertainty: 30
#     }
#     departure {
#       delay: 0
#       time: 1765934263
#       uncertainty: 30
#     }
#     stop_id: "M70-2"
#   }
#   stop_time_update {
#     arrival {
#       delay: 0
#       time: 1765934407
#       uncertainty: 30
#     }
#     departure {
#       delay: 0
#       time: 1765934425
#       uncertainty: 30
#     }
#     stop_id: "M60-2"
#   }
#   stop_time_update {
#     arrival {
#       delay: 0
#       time: 1765934527
#       uncertainty: 30
#     }
#     departure {
#       delay: 0
#       time: 1765934551
#       uncertainty: 30
#     }
#     stop_id: "M50-2"
#   }
#   stop_time_update {
#     arrival {
#       delay: 0
#       time: 1765934671
#       uncertainty: 30
#     }
#     departure {
#       delay: 0
#       time: 1765934695
#       uncertainty: 30
#     }
#     stop_id: "M40-2"
#   }
#   stop_time_update {
#     arrival {
#       delay: 0
#       time: 1765934767
#       uncertainty: 30
#     }
#     departure {
#       delay: 0
#       time: 1765934797
#       uncertainty: 30
#     }
#     stop_id: "M30-2"
#   }
#   stop_time_update {
#     arrival {
#       delay: 0
#       time: 1765934863
#       uncertainty: 30
#     }
#     departure {
#       delay: 0
#       time: 1765934893
#       uncertainty: 30
#     }
#     stop_id: "M20-2"
#   }
#   stop_time_update {
#     arrival {
#       delay: 0
#       time: 1765934959
#       uncertainty: 30
#     }
#     departure {
#       delay: 0
#       time: 1765934995
#       uncertainty: 30
#     }
#     stop_id: "M16-2"
#   }
#   stop_time_update {
#     arrival {
#       delay: 0
#       time: 1765935391
#       uncertainty: 30
#     }
#     departure {
#       delay: 0
#       time: 1765935421
#       uncertainty: 30
#     }
#     stop_id: "M10-2"
#   }
#   stop_time_update {
#     arrival {
#       delay: 0
#       time: 1765935737
#       uncertainty: 30
#     }
#     departure {
#       delay: 0
#       time: 1765935773
#       uncertainty: 30
#     }
#     stop_id: "A10-1"
#   }
#   stop_time_update {
#     arrival {
#       delay: 0
#       time: 1765935990
#       uncertainty: 30
#     }
#     departure {
#       delay: 0
#       time: 1765936008
#       uncertainty: 30
#     }
#     stop_id: "A20-1"
#   }
#   stop_time_update {
#     arrival {
#       delay: 0
#       time: 1765936182
#       uncertainty: 30
#     }
#     departure {
#       delay: 0
#       time: 1765936200
#       uncertainty: 30
#     }
#     stop_id: "A30-1"
#   }
#   stop_time_update {
#     arrival {
#       delay: 0
#       time: 1765936427
#       uncertainty: 30
#     }
#     departure {
#       delay: 0
#       time: 1765936445
#       uncertainty: 30
#     }
#     stop_id: "A40-1"
#   }
#   stop_time_update {
#     arrival {
#       delay: 0
#       time: 1765936653
#       uncertainty: 30
#     }
#     departure {
#       delay: 0
#       time: 1765936689
#       uncertainty: 30
#     }
#     stop_id: "A50-1"
#   }
#   stop_time_update {
#     arrival {
#       delay: 0
#       time: 1765936922
#       uncertainty: 30
#     }
#     departure {
#       delay: 0
#       time: 1765936940
#       uncertainty: 30
#     }
#     stop_id: "A60-1"
#   }
#   stop_time_update {
#     arrival {
#       delay: 0
#       time: 1765937175
#       uncertainty: 30
#     }
#     departure {
#       delay: 0
#       time: 1765937193
#       uncertainty: 30
#     }
#     stop_id: "A70-1"
#   }
#   stop_time_update {
#     arrival {
#       delay: 0
#       time: 1765937499
#       uncertainty: 30
#     }
#     departure {
#       delay: 0
#       time: 1765937517
#       uncertainty: 30
#     }
#     stop_id: "A80-1"
#   }
#   stop_time_update {
#     arrival {
#       delay: 0
#       time: 1765937761
#       uncertainty: 30
#     }
#     departure {
#       delay: 0
#       time: 1765937779
#       uncertainty: 30
#     }
#     stop_id: "A90-1"
#   }
#   stop_time_update {
#     arrival {
#       delay: 0
#       time: 1765938137
#       uncertainty: 30
#     }
#     departure {
#       delay: 0
#       time: 1765938155
#       uncertainty: 30
#     }
#     stop_id: "S20-1"
#   }
#   stop_time_update {
#     arrival {
#       delay: 0
#       time: 1765938598
#       uncertainty: 30
#     }
#     departure {
#       delay: 0
#       time: 1765938616
#       uncertainty: 30
#     }
#     stop_id: "S40-1"
#   }
#   vehicle {
#     label: "3-door"
#   }
# }
#
#
# 10
# id: "1771658"
# trip_update {
#   trip {
#     trip_id: "1771658"
#     schedule_relationship: SCHEDULED
#   }
#   stop_time_update {
#     arrival {
#       delay: 113
#       time: 1765932287
#       uncertainty: 30
#     }
#     departure {
#       delay: 113
#       time: 1765932305
#       uncertainty: 30
#     }
#     stop_id: "A10-2"
#   }
#   stop_time_update {
#     arrival {
#       delay: 105
#       time: 1765932597
#       uncertainty: 30
#     }
#     departure {
#       delay: 105
#       time: 1765932620
#       uncertainty: 30
#     }
#     stop_id: "M10-1"
#   }
#   stop_time_update {
#     arrival {
#       delay: 62
#       time: 1765932969
#       uncertainty: 30
#     }
#     departure {
#       delay: 62
#       time: 1765932993
#       uncertainty: 30
#     }
#     stop_id: "M16-1"
#   }
#   stop_time_update {
#     arrival {
#       delay: 64
#       time: 1765933073
#       uncertainty: 30
#     }
#     departure {
#       delay: 64
#       time: 1765933100
#       uncertainty: 30
#     }
#     stop_id: "M20-1"
#   }
#   stop_time_update {
#     arrival {
#       delay: 33
#       time: 1765933143
#       uncertainty: 30
#     }
#     departure {
#       delay: 33
#       time: 1765933167
#       uncertainty: 30
#     }
#     stop_id: "M30-1"
#   }
#   stop_time_update {
#     arrival {
#       delay: 33
#       time: 1765933245
#       uncertainty: 30
#     }
#     departure {
#       delay: 33
#       time: 1765933268
#       uncertainty: 30
#     }
#     stop_id: "M40-1"
#   }
#   stop_time_update {
#     arrival {
#       delay: 30
#       time: 1765933387
#       uncertainty: 30
#     }
#     departure {
#       delay: 30
#       time: 1765933405
#       uncertainty: 30
#     }
#     stop_id: "M50-1"
#   }
#   stop_time_update {
#     arrival {
#       delay: 33
#       time: 1765933510
#       uncertainty: 30
#     }
#     departure {
#       delay: 33
#       time: 1765933528
#       uncertainty: 30
#     }
#     stop_id: "M60-1"
#   }
#   stop_time_update {
#     arrival {
#       delay: 31
#       time: 1765933676
#       uncertainty: 30
#     }
#     departure {
#       delay: 31
#       time: 1765933694
#       uncertainty: 30
#     }
#     stop_id: "M70-1"
#   }
#   stop_time_update {
#     arrival {
#       delay: 0
#       time: 1765933783
#       uncertainty: 30
#     }
#     departure {
#       delay: 0
#       time: 1765933801
#       uncertainty: 30
#     }
#     stop_id: "M80-1"
#   }
#   vehicle {
#     label: "3-door"
#   }
# }
#
#
# 11
# id: "1771659"
# trip_update {
#   trip {
#     trip_id: "1771659"
#     schedule_relationship: SCHEDULED
#   }
#   stop_time_update {
#     arrival {
#       delay: 141
#       time: 1765932324
#       uncertainty: 30
#     }
#     departure {
#       delay: 141
#       time: 1765932342
#       uncertainty: 30
#     }
#     stop_id: "A60-2"
#   }
#   stop_time_update {
#     arrival {
#       delay: 136
#       time: 1765932561
#       uncertainty: 30
#     }
#     departure {
#       delay: 136
#       time: 1765932579
#       uncertainty: 30
#     }
#     stop_id: "A50-2"
#   }
#   stop_time_update {
#     arrival {
#       delay: 121
#       time: 1765932775
#       uncertainty: 30
#     }
#     departure {
#       delay: 121
#       time: 1765932793
#       uncertainty: 30
#     }
#     stop_id: "A40-2"
#   }
#   stop_time_update {
#     arrival {
#       delay: 107
#       time: 1765933014
#       uncertainty: 30
#     }
#     departure {
#       delay: 107
#       time: 1765933032
#       uncertainty: 30
#     }
#     stop_id: "A30-2"
#   }
#   stop_time_update {
#     arrival {
#       delay: 97
#       time: 1765933203
#       uncertainty: 30
#     }
#     departure {
#       delay: 97
#       time: 1765933221
#       uncertainty: 30
#     }
#     stop_id: "A20-2"
#   }
#   stop_time_update {
#     arrival {
#       delay: 64
#       time: 1765933438
#       uncertainty: 30
#     }
#     departure {
#       delay: 64
#       time: 1765933456
#       uncertainty: 30
#     }
#     stop_id: "A10-2"
#   }
#   stop_time_update {
#     arrival {
#       delay: 76
#       time: 1765933769
#       uncertainty: 30
#     }
#     departure {
#       delay: 76
#       time: 1765933792
#       uncertainty: 30
#     }
#     stop_id: "M10-1"
#   }
#   stop_time_update {
#     arrival {
#       delay: 32
#       time: 1765934139
#       uncertainty: 30
#     }
#     departure {
#       delay: 32
#       time: 1765934163
#       uncertainty: 30
#     }
#     stop_id: "M16-1"
#   }
#   stop_time_update {
#     arrival {
#       delay: 38
#       time: 1765934247
#       uncertainty: 30
#     }
#     departure {
#       delay: 38
#       time: 1765934274
#       uncertainty: 30
#     }
#     stop_id: "M20-1"
#   }
#   stop_time_update {
#     arrival {
#       delay: 31
#       time: 1765934341
#       uncertainty: 30
#     }
#     departure {
#       delay: 31
#       time: 1765934365
#       uncertainty: 30
#     }
#     stop_id: "M30-1"
#   }
#   stop_time_update {
#     arrival {
#       delay: 0
#       time: 1765934413
#       uncertainty: 30
#     }
#     departure {
#       delay: 0
#       time: 1765934435
#       uncertainty: 30
#     }
#     stop_id: "M40-1"
#   }
#   stop_time_update {
#     arrival {
#       delay: 0
#       time: 1765934557
#       uncertainty: 30
#     }
#     departure {
#       delay: 0
#       time: 1765934575
#       uncertainty: 30
#     }
#     stop_id: "M50-1"
#   }
#   stop_time_update {
#     arrival {
#       delay: 0
#       time: 1765934677
#       uncertainty: 30
#     }
#     departure {
#       delay: 0
#       time: 1765934695
#       uncertainty: 30
#     }
#     stop_id: "M60-1"
#   }
#   stop_time_update {
#     arrival {
#       delay: 0
#       time: 1765934845
#       uncertainty: 30
#     }
#     departure {
#       delay: 0
#       time: 1765934863
#       uncertainty: 30
#     }
#     stop_id: "M70-1"
#   }
#   stop_time_update {
#     arrival {
#       delay: 0
#       time: 1765934983
#       uncertainty: 30
#     }
#     departure {
#       delay: 0
#       time: 1765935001
#       uncertainty: 30
#     }
#     stop_id: "M80-1"
#   }
#   vehicle {
#     label: "3-door"
#   }
# }
#
#
# 12
# id: "1771704"
# trip_update {
#   trip {
#     trip_id: "1771704"
#     schedule_relationship: SCHEDULED
#   }
#   stop_time_update {
#     arrival {
#       delay: 66
#       time: 1765932305
#       uncertainty: 30
#     }
#     departure {
#       delay: 66
#       time: 1765932323
#       uncertainty: 30
#     }
#     stop_id: "A80-2"
#   }
#   stop_time_update {
#     arrival {
#       delay: 35
#       time: 1765932577
#       uncertainty: 30
#     }
#     departure {
#       delay: 35
#       time: 1765932595
#       uncertainty: 30
#     }
#     stop_id: "A70-2"
#   }
#   stop_time_update {
#     arrival {
#       delay: 47
#       time: 1765932831
#       uncertainty: 30
#     }
#     departure {
#       delay: 47
#       time: 1765932849
#       uncertainty: 30
#     }
#     stop_id: "A60-2"
#   }
#   stop_time_update {
#     arrival {
#       delay: 44
#       time: 1765933069
#       uncertainty: 30
#     }
#     departure {
#       delay: 44
#       time: 1765933087
#       uncertainty: 30
#     }
#     stop_id: "A50-2"
#   }
#   stop_time_update {
#     arrival {
#       delay: 0
#       time: 1765933254
#       uncertainty: 30
#     }
#     departure {
#       delay: 0
#       time: 1765933272
#       uncertainty: 30
#     }
#     stop_id: "A40-2"
#   }
#   stop_time_update {
#     arrival {
#       delay: 0
#       time: 1765933507
#       uncertainty: 30
#     }
#     departure {
#       delay: 0
#       time: 1765933525
#       uncertainty: 30
#     }
#     stop_id: "A30-2"
#   }
#   stop_time_update {
#     arrival {
#       delay: 0
#       time: 1765933706
#       uncertainty: 30
#     }
#     departure {
#       delay: 0
#       time: 1765933724
#       uncertainty: 30
#     }
#     stop_id: "A20-2"
#   }
#   stop_time_update {
#     arrival {
#       delay: 0
#       time: 1765933975
#       uncertainty: 30
#     }
#     departure {
#       delay: 0
#       time: 1765933993
#       uncertainty: 30
#     }
#     stop_id: "A10-2"
#   }
#   stop_time_update {
#     arrival {
#       delay: 0
#       time: 1765934149
#       uncertainty: 30
#     }
#     departure {
#       delay: 0
#       time: 1765934173
#       uncertainty: 30
#     }
#     stop_id: "K10-1"
#   }
#   stop_time_update {
#     arrival {
#       delay: 0
#       time: 1765934233
#       uncertainty: 30
#     }
#     departure {
#       delay: 0
#       time: 1765934287
#       uncertainty: 30
#     }
#     stop_id: "K20-1"
#   }
#   stop_time_update {
#     arrival {
#       delay: 0
#       time: 1765934478
#       uncertainty: 30
#     }
#     departure {
#       delay: 0
#       time: 1765934520
#       uncertainty: 30
#     }
#     stop_id: "K30-1"
#   }
#   stop_time_update {
#     arrival {
#       delay: 0
#       time: 1765934694
#       uncertainty: 30
#     }
#     departure {
#       delay: 0
#       time: 1765934712
#       uncertainty: 30
#     }
#     stop_id: "R10-1"
#   }
#   stop_time_update {
#     arrival {
#       delay: 0
#       time: 1765934832
#       uncertainty: 30
#     }
#     departure {
#       delay: 0
#       time: 1765934856
#       uncertainty: 30
#     }
#     stop_id: "R20-1"
#   }
#   stop_time_update {
#     arrival {
#       delay: 0
#       time: 1765934976
#       uncertainty: 30
#     }
#     departure {
#       delay: 0
#       time: 1765934994
#       uncertainty: 30
#     }
#     stop_id: "R30-1"
#   }
#   stop_time_update {
#     arrival {
#       delay: 0
#       time: 1765935168
#       uncertainty: 30
#     }
#     departure {
#       delay: 0
#       time: 1765935186
#       uncertainty: 30
#     }
#     stop_id: "R40-1"
#   }
#   stop_time_update {
#     arrival {
#       delay: 0
#       time: 1765935349
#       uncertainty: 30
#     }
#     departure {
#       delay: 0
#       time: 1765935397
#       uncertainty: 30
#     }
#     stop_id: "R50-1"
#   }
#   vehicle {
#     label: "3-door"
#   }
# }
#
#
# 13
# id: "1771705"
# trip_update {
#   trip {
#     trip_id: "1771705"
#     schedule_relationship: SCHEDULED
#   }
#   stop_time_update {
#     arrival {
#       delay: 0
#       time: 1765932353
#       uncertainty: 30
#     }
#     departure {
#       delay: 0
#       time: 1765932371
#       uncertainty: 30
#     }
#     stop_id: "S40-2"
#   }
#   stop_time_update {
#     arrival {
#       delay: 0
#       time: 1765932810
#       uncertainty: 30
#     }
#     departure {
#       delay: 0
#       time: 1765932828
#       uncertainty: 30
#     }
#     stop_id: "S20-2"
#   }
#   stop_time_update {
#     arrival {
#       delay: 0
#       time: 1765933186
#       uncertainty: 30
#     }
#     departure {
#       delay: 0
#       time: 1765933204
#       uncertainty: 30
#     }
#     stop_id: "A90-2"
#   }
#   stop_time_update {
#     arrival {
#       delay: 0
#       time: 1765933439
#       uncertainty: 30
#     }
#     departure {
#       delay: 0
#       time: 1765933457
#       uncertainty: 30
#     }
#     stop_id: "A80-2"
#   }
#   stop_time_update {
#     arrival {
#       delay: 0
#       time: 1765933743
#       uncertainty: 30
#     }
#     departure {
#       delay: 0
#       time: 1765933761
#       uncertainty: 30
#     }
#     stop_id: "A70-2"
#   }
#   stop_time_update {
#     arrival {
#       delay: 0
#       time: 1765933984
#       uncertainty: 30
#     }
#     departure {
#       delay: 0
#       time: 1765934002
#       uncertainty: 30
#     }
#     stop_id: "A60-2"
#   }
#   stop_time_update {
#     arrival {
#       delay: 0
#       time: 1765934225
#       uncertainty: 30
#     }
#     departure {
#       delay: 0
#       time: 1765934243
#       uncertainty: 30
#     }
#     stop_id: "A50-2"
#   }
#   stop_time_update {
#     arrival {
#       delay: 0
#       time: 1765934454
#       uncertainty: 30
#     }
#     departure {
#       delay: 0
#       time: 1765934472
#       uncertainty: 30
#     }
#     stop_id: "A40-2"
#   }
#   stop_time_update {
#     arrival {
#       delay: 0
#       time: 1765934707
#       uncertainty: 30
#     }
#     departure {
#       delay: 0
#       time: 1765934725
#       uncertainty: 30
#     }
#     stop_id: "A30-2"
#   }
#   stop_time_update {
#     arrival {
#       delay: 0
#       time: 1765934906
#       uncertainty: 30
#     }
#     departure {
#       delay: 0
#       time: 1765934924
#       uncertainty: 30
#     }
#     stop_id: "A20-2"
#   }
#   stop_time_update {
#     arrival {
#       delay: 0
#       time: 1765935175
#       uncertainty: 30
#     }
#     departure {
#       delay: 0
#       time: 1765935193
#       uncertainty: 30
#     }
#     stop_id: "A10-2"
#   }
#   stop_time_update {
#     arrival {
#       delay: 0
#       time: 1765935349
#       uncertainty: 30
#     }
#     departure {
#       delay: 0
#       time: 1765935373
#       uncertainty: 30
#     }
#     stop_id: "K10-1"
#   }
#   stop_time_update {
#     arrival {
#       delay: 0
#       time: 1765935433
#       uncertainty: 30
#     }
#     departure {
#       delay: 0
#       time: 1765935487
#       uncertainty: 30
#     }
#     stop_id: "K20-1"
#   }
#   stop_time_update {
#     arrival {
#       delay: 0
#       time: 1765935678
#       uncertainty: 30
#     }
#     departure {
#       delay: 0
#       time: 1765935720
#       uncertainty: 30
#     }
#     stop_id: "K30-1"
#   }
#   stop_time_update {
#     arrival {
#       delay: 0
#       time: 1765935894
#       uncertainty: 30
#     }
#     departure {
#       delay: 0
#       time: 1765935912
#       uncertainty: 30
#     }
#     stop_id: "R10-1"
#   }
#   stop_time_update {
#     arrival {
#       delay: 0
#       time: 1765936032
#       uncertainty: 30
#     }
#     departure {
#       delay: 0
#       time: 1765936056
#       uncertainty: 30
#     }
#     stop_id: "R20-1"
#   }
#   stop_time_update {
#     arrival {
#       delay: 0
#       time: 1765936176
#       uncertainty: 30
#     }
#     departure {
#       delay: 0
#       time: 1765936194
#       uncertainty: 30
#     }
#     stop_id: "R30-1"
#   }
#   stop_time_update {
#     arrival {
#       delay: 0
#       time: 1765936368
#       uncertainty: 30
#     }
#     departure {
#       delay: 0
#       time: 1765936386
#       uncertainty: 30
#     }
#     stop_id: "R40-1"
#   }
#   stop_time_update {
#     arrival {
#       delay: 0
#       time: 1765936549
#       uncertainty: 30
#     }
#     departure {
#       delay: 0
#       time: 1765936597
#       uncertainty: 30
#     }
#     stop_id: "R50-1"
#   }
#   vehicle {
#     label: "3-door"
#   }
# }
#
#
# 14
# id: "1771888"
# trip_update {
#   trip {
#     trip_id: "1771888"
#     schedule_relationship: SCHEDULED
#   }
#   stop_time_update {
#     arrival {
#       delay: 51
#       time: 1765932115
#       uncertainty: 30
#     }
#     departure {
#       delay: 51
#       time: 1765932133
#       uncertainty: 30
#     }
#     stop_id: "S40-1"
#   }
#   vehicle {
#     label: "3-door"
#   }
# }
#
#
# 15
# id: "1771706"
# trip_update {
#   trip {
#     trip_id: "1771706"
#     schedule_relationship: SCHEDULED
#   }
#   stop_time_update {
#     arrival {
#       delay: 0
#       time: 1765932436
#       uncertainty: 30
#     }
#     departure {
#       delay: 0
#       time: 1765933312
#       uncertainty: 30
#     }
#     stop_id: "S50-2"
#   }
#   stop_time_update {
#     arrival {
#       delay: 0
#       time: 1765933553
#       uncertainty: 30
#     }
#     departure {
#       delay: 0
#       time: 1765933571
#       uncertainty: 30
#     }
#     stop_id: "S40-2"
#   }
#   stop_time_update {
#     arrival {
#       delay: 0
#       time: 1765934010
#       uncertainty: 30
#     }
#     departure {
#       delay: 0
#       time: 1765934028
#       uncertainty: 30
#     }
#     stop_id: "S20-2"
#   }
#   stop_time_update {
#     arrival {
#       delay: 0
#       time: 1765934386
#       uncertainty: 30
#     }
#     departure {
#       delay: 0
#       time: 1765934404
#       uncertainty: 30
#     }
#     stop_id: "A90-2"
#   }
#   stop_time_update {
#     arrival {
#       delay: 0
#       time: 1765934639
#       uncertainty: 30
#     }
#     departure {
#       delay: 0
#       time: 1765934657
#       uncertainty: 30
#     }
#     stop_id: "A80-2"
#   }
#   stop_time_update {
#     arrival {
#       delay: 0
#       time: 1765934943
#       uncertainty: 30
#     }
#     departure {
#       delay: 0
#       time: 1765934961
#       uncertainty: 30
#     }
#     stop_id: "A70-2"
#   }
#   stop_time_update {
#     arrival {
#       delay: 0
#       time: 1765935184
#       uncertainty: 30
#     }
#     departure {
#       delay: 0
#       time: 1765935202
#       uncertainty: 30
#     }
#     stop_id: "A60-2"
#   }
#   stop_time_update {
#     arrival {
#       delay: 0
#       time: 1765935425
#       uncertainty: 30
#     }
#     departure {
#       delay: 0
#       time: 1765935443
#       uncertainty: 30
#     }
#     stop_id: "A50-2"
#   }
#   stop_time_update {
#     arrival {
#       delay: 0
#       time: 1765935654
#       uncertainty: 30
#     }
#     departure {
#       delay: 0
#       time: 1765935672
#       uncertainty: 30
#     }
#     stop_id: "A40-2"
#   }
#   stop_time_update {
#     arrival {
#       delay: 0
#       time: 1765935907
#       uncertainty: 30
#     }
#     departure {
#       delay: 0
#       time: 1765935925
#       uncertainty: 30
#     }
#     stop_id: "A30-2"
#   }
#   stop_time_update {
#     arrival {
#       delay: 0
#       time: 1765936106
#       uncertainty: 30
#     }
#     departure {
#       delay: 0
#       time: 1765936124
#       uncertainty: 30
#     }
#     stop_id: "A20-2"
#   }
#   stop_time_update {
#     arrival {
#       delay: 0
#       time: 1765936375
#       uncertainty: 30
#     }
#     departure {
#       delay: 0
#       time: 1765936393
#       uncertainty: 30
#     }
#     stop_id: "A10-2"
#   }
#   stop_time_update {
#     arrival {
#       delay: 0
#       time: 1765936549
#       uncertainty: 30
#     }
#     departure {
#       delay: 0
#       time: 1765936573
#       uncertainty: 30
#     }
#     stop_id: "K10-1"
#   }
#   stop_time_update {
#     arrival {
#       delay: 0
#       time: 1765936633
#       uncertainty: 30
#     }
#     departure {
#       delay: 0
#       time: 1765936687
#       uncertainty: 30
#     }
#     stop_id: "K20-1"
#   }
#   stop_time_update {
#     arrival {
#       delay: 0
#       time: 1765936878
#       uncertainty: 30
#     }
#     departure {
#       delay: 0
#       time: 1765936920
#       uncertainty: 30
#     }
#     stop_id: "K30-1"
#   }
#   stop_time_update {
#     arrival {
#       delay: 0
#       time: 1765937094
# ...
#     }
#     stop_id: "M70-1"
#   }
#   stop_time_update {
#     arrival {
#       delay: 0
#       time: 1765936603
#       uncertainty: 30
#     }
#     departure {
#       delay: 0
#       time: 1765936621
#       uncertainty: 30
#     }
#     stop_id: "M80-1"
#   }
#   vehicle {
#     label: "2-door"
#   }
# }
#
#
# 70
# id: "1771553"
# trip_update {
#   trip {
#     trip_id: "1771553"
#     schedule_relationship: SCHEDULED
#   }
#   stop_time_update {
#     arrival {
#       delay: 0
#       time: 1765934163
#       uncertainty: 30
#     }
#     departure {
#       delay: 0
#       time: 1765934168
#       uncertainty: 30
#     }
#     stop_id: "L30-2"
#   }
#   stop_time_update {
#     arrival {
#       delay: 0
#       time: 1765934351
#       uncertainty: 30
#     }
#     departure {
#       delay: 0
#       time: 1765934369
#       uncertainty: 30
#     }
#     stop_id: "L20-2"
#   }
#   stop_time_update {
#     arrival {
#       delay: 0
#       time: 1765934958
#       uncertainty: 30
#     }
#     departure {
#       delay: 0
#       time: 1765934976
#       uncertainty: 30
#     }
#     stop_id: "L10-2"
#   }
#   stop_time_update {
#     arrival {
#       delay: 0
#       time: 1765935245
#       uncertainty: 30
#     }
#     departure {
#       delay: 0
#       time: 1765935263
#       uncertainty: 30
#     }
#     stop_id: "A50-2"
#   }
#   stop_time_update {
#     arrival {
#       delay: 0
#       time: 1765935474
#       uncertainty: 30
#     }
#     departure {
#       delay: 0
#       time: 1765935492
#       uncertainty: 30
#     }
#     stop_id: "A40-2"
#   }
#   stop_time_update {
#     arrival {
#       delay: 0
#       time: 1765935727
#       uncertainty: 30
#     }
#     departure {
#       delay: 0
#       time: 1765935745
#       uncertainty: 30
#     }
#     stop_id: "A30-2"
#   }
#   stop_time_update {
#     arrival {
#       delay: 0
#       time: 1765935926
#       uncertainty: 30
#     }
#     departure {
#       delay: 0
#       time: 1765935944
#       uncertainty: 30
#     }
#     stop_id: "A20-2"
#   }
#   stop_time_update {
#     arrival {
#       delay: 0
#       time: 1765936195
#       uncertainty: 30
#     }
#     departure {
#       delay: 0
#       time: 1765936213
#       uncertainty: 30
#     }
#     stop_id: "A10-2"
#   }
#   stop_time_update {
#     arrival {
#       delay: 0
#       time: 1765936513
#       uncertainty: 30
#     }
#     departure {
#       delay: 0
#       time: 1765936543
#       uncertainty: 30
#     }
#     stop_id: "M10-1"
#   }
#   stop_time_update {
#     arrival {
#       delay: 0
#       time: 1765936927
#       uncertainty: 30
#     }
#     departure {
#       delay: 0
#       time: 1765936963
#       uncertainty: 30
#     }
#     stop_id: "M16-1"
#   }
#   stop_time_update {
#     arrival {
#       delay: 0
#       time: 1765937029
#       uncertainty: 30
#     }
#     departure {
#       delay: 0
#       time: 1765937059
#       uncertainty: 30
#     }
#     stop_id: "M20-1"
#   }
#   stop_time_update {
#     arrival {
#       delay: 0
#       time: 1765937131
#       uncertainty: 30
#     }
#     departure {
#       delay: 0
#       time: 1765937161
#       uncertainty: 30
#     }
#     stop_id: "M30-1"
#   }
#   stop_time_update {
#     arrival {
#       delay: 0
#       time: 1765937233
#       uncertainty: 30
#     }
#     departure {
#       delay: 0
#       time: 1765937257
#       uncertainty: 30
#     }
#     stop_id: "M40-1"
#   }
#   stop_time_update {
#     arrival {
#       delay: 0
#       time: 1765937377
#       uncertainty: 30
#     }
#     departure {
#       delay: 0
#       time: 1765937395
#       uncertainty: 30
#     }
#     stop_id: "M50-1"
#   }
#   stop_time_update {
#     arrival {
#       delay: 0
#       time: 1765937497
#       uncertainty: 30
#     }
#     departure {
#       delay: 0
#       time: 1765937515
#       uncertainty: 30
#     }
#     stop_id: "M60-1"
#   }
#   stop_time_update {
#     arrival {
#       delay: 0
#       time: 1765937665
#       uncertainty: 30
#     }
#     departure {
#       delay: 0
#       time: 1765937683
#       uncertainty: 30
#     }
#     stop_id: "M70-1"
#   }
#   stop_time_update {
#     arrival {
#       delay: 0
#       time: 1765937803
#       uncertainty: 30
#     }
#     departure {
#       delay: 0
#       time: 1765937821
#       uncertainty: 30
#     }
#     stop_id: "M80-1"
#   }
#   vehicle {
#     label: "2-door"
#   }
# }
#
#
# 71
# id: "1771457"
# trip_update {
#   trip {
#     trip_id: "1771457"
#     schedule_relationship: SCHEDULED
#   }
#   stop_time_update {
#     arrival {
#       delay: 174
#       time: 1765932102
#       uncertainty: 30
#     }
#     departure {
#       delay: 174
#       time: 1765932124
#       uncertainty: 30
#     }
#     stop_id: "M50-2"
#   }
#   stop_time_update {
#     arrival {
#       delay: 163
#       time: 1765932235
#       uncertainty: 30
#     }
#     departure {
#       delay: 163
#       time: 1765932259
#       uncertainty: 30
#     }
#     stop_id: "M40-2"
#   }
#   stop_time_update {
#     arrival {
#       delay: 160
#       time: 1765932328
#       uncertainty: 30
#     }
#     departure {
#       delay: 160
#       time: 1765932358
#       uncertainty: 30
#     }
#     stop_id: "M30-2"
#   }
#   stop_time_update {
#     arrival {
#       delay: 159
#       time: 1765932423
#       uncertainty: 30
#     }
#     departure {
#       delay: 159
#       time: 1765932449
#       uncertainty: 30
#     }
#     stop_id: "M20-2"
#   }
#   stop_time_update {
#     arrival {
#       delay: 149
#       time: 1765932509
#       uncertainty: 30
#     }
#     departure {
#       delay: 149
#       time: 1765932541
#       uncertainty: 30
#     }
#     stop_id: "M16-2"
#   }
#   stop_time_update {
#     arrival {
#       delay: 126
#       time: 1765932918
#       uncertainty: 30
#     }
#     departure {
#       delay: 126
#       time: 1765932943
#       uncertainty: 30
#     }
#     stop_id: "M10-2"
#   }
#   stop_time_update {
#     arrival {
#       delay: 97
#       time: 1765933235
#       uncertainty: 30
#     }
#     departure {
#       delay: 97
#       time: 1765933255
#       uncertainty: 30
#     }
#     stop_id: "A10-1"
#   }
#   stop_time_update {
#     arrival {
#       delay: 68
#       time: 1765933459
#       uncertainty: 30
#     }
#     departure {
#       delay: 68
#       time: 1765933477
#       uncertainty: 30
#     }
#     stop_id: "A20-1"
#   }
#   stop_time_update {
#     arrival {
#       delay: 62
#       time: 1765933645
#       uncertainty: 30
#     }
#     departure {
#       delay: 62
#       time: 1765933663
#       uncertainty: 30
#     }
#     stop_id: "A30-1"
#   }
#   stop_time_update {
#     arrival {
#       delay: 66
#       time: 1765933894
#       uncertainty: 30
#     }
#     departure {
#       delay: 66
#       time: 1765933912
#       uncertainty: 30
#     }
#     stop_id: "A40-1"
#   }
#   stop_time_update {
#     arrival {
#       delay: 32
#       time: 1765934086
#       uncertainty: 30
#     }
#     departure {
#       delay: 32
#       time: 1765934115
#       uncertainty: 30
#     }
#     stop_id: "A50-1"
#   }
#   stop_time_update {
#     arrival {
#       delay: 31
#       time: 1765934368
#       uncertainty: 30
#     }
#     departure {
#       delay: 31
#       time: 1765934386
#       uncertainty: 30
#     }
#     stop_id: "L10-1"
#   }
#   stop_time_update {
#     arrival {
#       delay: 32
#       time: 1765934947
#       uncertainty: 30
#     }
#     departure {
#       delay: 32
#       time: 1765934965
#       uncertainty: 30
#     }
#     stop_id: "L20-1"
#   }
#   vehicle {
#     label: "3-door"
#   }
# }
#
#
# 72
# id: "666"
# trip_update {
#   trip {
#     trip_id: "666"
#     schedule_relationship: SCHEDULED
#   }
#   stop_time_update {
#     arrival {
#       delay: 0
#       time: 1765932491
#       uncertainty: 30
#     }
#     departure {
#       delay: 0
#       time: 1765932521
#       uncertainty: 30
#     }
#     stop_id: "E20-1"
#   }
#   vehicle {
#     label: "2-door"
#   }
# }
#
#
# 73
# id: "668"
# trip_update {
#   trip {
#     trip_id: "668"
#     schedule_relationship: SCHEDULED
#   }
#   stop_time_update {
#     arrival {
#       delay: 0
#       time: 1765933691
#       uncertainty: 30
#     }
#     departure {
#       delay: 0
#       time: 1765933721
#       uncertainty: 30
#     }
#     stop_id: "E20-1"
#   }
#   vehicle {
#     label: "2-door"
#   }
# }
#
#
# 74
# id: "670"
# trip_update {
#   trip {
#     trip_id: "670"
#     schedule_relationship: SCHEDULED
#   }
#   stop_time_update {
#     arrival {
#       delay: 0
#       time: 1765934891
#       uncertainty: 30
#     }
#     departure {
#       delay: 0
#       time: 1765934921
#       uncertainty: 30
#     }
#     stop_id: "E20-1"
#   }
#   vehicle {
#     label: "2-door"
#   }
# }
#
#
# 75
# id: "672"
# trip_update {
#   trip {
#     trip_id: "672"
#     schedule_relationship: SCHEDULED
#   }
#   stop_time_update {
#     arrival {
#       delay: 0
#       time: 1765936091
#       uncertainty: 30
#     }
#     departure {
#       delay: 0
#       time: 1765936121
#       uncertainty: 30
#     }
#     stop_id: "E20-1"
#   }
#   vehicle {
#     label: "2-door"
#   }
# }
#
#
# 76
# id: "673"
# trip_update {
#   trip {
#     trip_id: "673"
#     schedule_relationship: SCHEDULED
#   }
#   stop_time_update {
#     arrival {
#       delay: 0
#       time: 1765932228
#       uncertainty: 30
#     }
#     departure {
#       delay: 0
#       time: 1765932528
#       uncertainty: 30
#     }
#     stop_id: "E30-2"
#   }
#   stop_time_update {
#     arrival {
#       delay: 0
#       time: 1765932972
#       uncertainty: 30
#     }
#     departure {
#       delay: 0
#       time: 1765933002
#       uncertainty: 30
#     }
#     stop_id: "E20-2"
#   }
#   vehicle {
#     label: "2-door"
#   }
# }
#
#
# 77
# id: "674"
# trip_update {
#   trip {
#     trip_id: "674"
#     schedule_relationship: SCHEDULED
#   }
#   stop_time_update {
#     arrival {
#       delay: 0
#       time: 1765937291
#       uncertainty: 30
#     }
#     departure {
#       delay: 0
#       time: 1765937321
#       uncertainty: 30
#     }
#     stop_id: "E20-1"
#   }
#   vehicle {
#     label: "2-door"
#   }
# }
#
#
# 78
# id: "675"
# trip_update {
#   trip {
#     trip_id: "675"
#     schedule_relationship: SCHEDULED
#   }
#   stop_time_update {
#     arrival {
#       delay: 0
#       time: 1765933428
#       uncertainty: 30
#     }
#     departure {
#       delay: 0
#       time: 1765933728
#       uncertainty: 30
#     }
#     stop_id: "E30-2"
#   }
#   stop_time_update {
#     arrival {
#       delay: 0
#       time: 1765934172
#       uncertainty: 30
#     }
#     departure {
#       delay: 0
#       time: 1765934202
#       uncertainty: 30
#     }
#     stop_id: "E20-2"
#   }
#   vehicle {
#     label: "2-door"
#   }
# }
#
#
# 79
# id: "677"
# trip_update {
#   trip {
#     trip_id: "677"
#     schedule_relationship: SCHEDULED
#   }
#   stop_time_update {
#     arrival {
#       delay: 0
#       time: 1765934628
#       uncertainty: 30
#     }
#     departure {
#       delay: 0
#       time: 1765934928
#       uncertainty: 30
#     }
#     stop_id: "E30-2"
#   }
#   stop_time_update {
#     arrival {
#       delay: 0
#       time: 1765935372
#       uncertainty: 30
#     }
#     departure {
#       delay: 0
#       time: 1765935402
#       uncertainty: 30
#     }
#     stop_id: "E20-2"
#   }
#   vehicle {
#     label: "2-door"
#   }
# }
#
#
# 80
# id: "679"
# trip_update {
#   trip {
#     trip_id: "679"
#     schedule_relationship: SCHEDULED
#   }
#   stop_time_update {
#     arrival {
#       delay: 0
#       time: 1765935828
#       uncertainty: 30
#     }
#     departure {
#       delay: 0
#       time: 1765936128
#       uncertainty: 30
#     }
#     stop_id: "E30-2"
#   }
#   stop_time_update {
#     arrival {
#       delay: 0
#       time: 1765936572
#       uncertainty: 30
#     }
#     departure {
#       delay: 0
#       time: 1765936602
#       uncertainty: 30
#     }
#     stop_id: "E20-2"
#   }
#   vehicle {
#     label: "2-door"
#   }
# }
#
#
# 81
# id: "681"
# trip_update {
#   trip {
#     trip_id: "681"
#     schedule_relationship: SCHEDULED
#   }
#   stop_time_update {
#     arrival {
#       delay: 0
#       time: 1765937028
#       uncertainty: 30
#     }
#     departure {
#       delay: 0
#       time: 1765937328
#       uncertainty: 30
#     }
#     stop_id: "E30-2"
#   }
#   vehicle {
#     label: "2-door"
#   }
# }
#
#
# 82
# id: "909162210"
# trip_update {
#   trip {
#     trip_id: "909162210"
#     schedule_relationship: ADDED
#   }
#   stop_time_update {
#     arrival {
#       delay: 587
#       time: 1765932259
#       uncertainty: 30
#     }
#     departure {
#       delay: 587
#       time: 1765932269
#       uncertainty: 30
#     }
#     stop_id: "A30-2"
#   }
#   stop_time_update {
#     arrival {
#       delay: 575
#       time: 1765932432
#       uncertainty: 30
#     }
#     departure {
#       delay: 575
#       time: 1765932442
#       uncertainty: 30
#     }
#     stop_id: "A20-2"
#   }
#   stop_time_update {
#     arrival {
#       delay: 562
#       time: 1765932669
#       uncertainty: 30
#     }
#     departure {
#       delay: 562
#       time: 1765932679
#       uncertainty: 30
#     }
#     stop_id: "A10-2"
#   }
#   stop_time_update {
#     arrival {
#       delay: 554
#       time: 1765932971
#       uncertainty: 30
#     }
#     departure {
#       delay: 554
#       time: 1765932981
#       uncertainty: 30
#     }
#     stop_id: "M10-1"
#   }
#   stop_time_update {
#     arrival {
#       delay: 541
#       time: 1765933352
#       uncertainty: 30
#     }
#     departure {
#       delay: 541
#       time: 1765933362
#       uncertainty: 30
#     }
#     stop_id: "M16-1"
#   }
#   stop_time_update {
#     arrival {
#       delay: 537
#       time: 1765933424
#       uncertainty: 30
#     }
#     departure {
#       delay: 537
#       time: 1765933434
#       uncertainty: 30
#     }
#     stop_id: "M20-1"
#   }
#   stop_time_update {
#     arrival {
#       delay: 528
#       time: 1765933497
#       uncertainty: 30
#     }
#     departure {
#       delay: 528
#       time: 1765933507
#       uncertainty: 30
#     }
#     stop_id: "M30-1"
#   }
#   stop_time_update {
#     arrival {
#       delay: 524
#       time: 1765933575
#       uncertainty: 30
#     }
#     departure {
#       delay: 524
#       time: 1765933585
#       uncertainty: 30
#     }
#     stop_id: "M40-1"
#   }
#   stop_time_update {
#     arrival {
#       delay: 518
#       time: 1765933699
#       uncertainty: 30
#     }
#     departure {
#       delay: 518
#       time: 1765933709
#       uncertainty: 30
#     }
#     stop_id: "M50-1"
#   }
#   stop_time_update {
#     arrival {
#       delay: 490
#       time: 1765933783
#       uncertainty: 30
#     }
#     departure {
#       delay: 490
#       time: 1765933793
#       uncertainty: 30
#     }
#     stop_id: "M60-1"
#   }
#   stop_time_update {
#     arrival {
#       delay: 488
#       time: 1765933941
#       uncertainty: 30
#     }
#     departure {
#       delay: 488
#       time: 1765933951
#       uncertainty: 30
#     }
#     stop_id: "M70-1"
#   }
#   stop_time_update {
#     arrival {
#       delay: 508
#       time: 1765934091
#       uncertainty: 30
#     }
#     departure {
#       delay: 508
#       time: 1765934101
#       uncertainty: 30
#     }
#     stop_id: "M80-1"
#   }
#   vehicle {
#     label: "3-door"
#   }
# }
#
#
# 83
# id: "1771490"
# trip_update {
#   trip {
#     trip_id: "1771490"
#     schedule_relationship: SCHEDULED
#   }
#   stop_time_update {
#     arrival {
#       delay: 378
#       time: 1765932314
#       uncertainty: 30
#     }
#     departure {
#       delay: 378
#       time: 1765932332
#       uncertainty: 30
#     }
#     stop_id: "L10-2"
#   }
#   stop_time_update {
#     arrival {
#       delay: 194
#       time: 1765932709
#       uncertainty: 30
#     }
#     departure {
#       delay: 194
#       time: 1765932727
#       uncertainty: 30
#     }
#     stop_id: "L20-1"
#   }
#   vehicle {
#     label: "3-door"
#   }
# }
#
#
# 84
# id: "1771491"
# trip_update {
#   trip {
#     trip_id: "1771491"
#     schedule_relationship: SCHEDULED
#   }
#   stop_time_update {
#     arrival {
#       delay: 189
#       time: 1765932127
#       uncertainty: 30
#     }
#     departure {
#       delay: 189
#       time: 1765932148
#       uncertainty: 30
#     }
#     stop_id: "A10-1"
#   }
#   stop_time_update {
#     arrival {
#       delay: 140
#       time: 1765932332
#       uncertainty: 30
#     }
#     departure {
#       delay: 140
#       time: 1765932350
#       uncertainty: 30
#     }
#     stop_id: "A20-1"
#   }
#   stop_time_update {
#     arrival {
#       delay: 190
#       time: 1765932574
#       uncertainty: 30
#     }
#     departure {
#       delay: 190
#       time: 1765932592
#       uncertainty: 30
#     }
#     stop_id: "A30-1"
#   }
#   stop_time_update {
#     arrival {
#       delay: 160
#       time: 1765932789
#       uncertainty: 30
#     }
#     departure {
#       delay: 160
#       time: 1765932807
#       uncertainty: 30
#     }
#     stop_id: "A40-1"
#   }
#   stop_time_update {
#     arrival {
#       delay: 168
#       time: 1765933023
#       uncertainty: 30
#     }
#     departure {
#       delay: 168
#       time: 1765933051
#       uncertainty: 30
#     }
#     stop_id: "A50-1"
#   }
#   stop_time_update {
#     arrival {
#       delay: 160
#       time: 1765933297
#       uncertainty: 30
#     }
#     departure {
#       delay: 160
#       time: 1765933315
#       uncertainty: 30
#     }
#     stop_id: "L10-1"
#   }
#   stop_time_update {
#     arrival {
#       delay: 161
#       time: 1765933876
#       uncertainty: 30
#     }
#     departure {
#       delay: 161
#       time: 1765933894
#       uncertainty: 30
#     }
#     stop_id: "L20-1"
#   }
#   vehicle {
#     label: "3-door"
#   }
# }

# %%
type(feed.entity)
# Out:
# google._upb._message.RepeatedCompositeContainer

# %%
datetime.fromtimestamp(1765934602)
# Out:
# datetime.datetime(2025, 12, 16, 17, 23, 22)

# %%
feed.ParseFromString(response.content)
for entity in feed.entity:
  if entity.HasField('trip_update'):
    print(entity.trip_update)
# Out:
# trip {
#   trip_id: "1771660"
#   schedule_relationship: SCHEDULED
# }
# stop_time_update {
#   arrival {
#     delay: 0
#     time: 1765931515
#     uncertainty: 30
#   }
#   departure {
#     delay: 0
#     time: 1765931525
#     uncertainty: 30
#   }
#   stop_id: "S50-1"
# }
# stop_time_update {
#   arrival {
#     delay: 0
#     time: 1765931753
#     uncertainty: 30
#   }
#   departure {
#     delay: 0
#     time: 1765931771
#     uncertainty: 30
#   }
#   stop_id: "S40-2"
# }
# stop_time_update {
#   arrival {
#     delay: 0
#     time: 1765932210
#     uncertainty: 30
#   }
#   departure {
#     delay: 0
#     time: 1765932228
#     uncertainty: 30
#   }
#   stop_id: "S20-2"
# }
# stop_time_update {
#   arrival {
#     delay: 0
#     time: 1765932586
#     uncertainty: 30
#   }
#   departure {
#     delay: 0
#     time: 1765932604
#     uncertainty: 30
#   }
#   stop_id: "A90-2"
# }
# stop_time_update {
#   arrival {
#     delay: 0
#     time: 1765932839
#     uncertainty: 30
#   }
#   departure {
#     delay: 0
#     time: 1765932857
#     uncertainty: 30
#   }
#   stop_id: "A80-2"
# }
# stop_time_update {
#   arrival {
#     delay: 0
#     time: 1765933143
#     uncertainty: 30
#   }
#   departure {
#     delay: 0
#     time: 1765933161
#     uncertainty: 30
#   }
#   stop_id: "A70-2"
# }
# stop_time_update {
#   arrival {
#     delay: 0
#     time: 1765933384
#     uncertainty: 30
#   }
#   departure {
#     delay: 0
#     time: 1765933402
#     uncertainty: 30
#   }
#   stop_id: "A60-2"
# }
# stop_time_update {
#   arrival {
#     delay: 0
#     time: 1765933625
#     uncertainty: 30
#   }
#   departure {
#     delay: 0
#     time: 1765933643
#     uncertainty: 30
#   }
#   stop_id: "A50-2"
# }
# stop_time_update {
#   arrival {
#     delay: 0
#     time: 1765933854
#     uncertainty: 30
#   }
#   departure {
#     delay: 0
#     time: 1765933872
#     uncertainty: 30
#   }
#   stop_id: "A40-2"
# }
# stop_time_update {
#   arrival {
#     delay: 0
#     time: 1765934107
#     uncertainty: 30
#   }
#   departure {
#     delay: 0
#     time: 1765934125
#     uncertainty: 30
#   }
#   stop_id: "A30-2"
# }
# stop_time_update {
#   arrival {
#     delay: 0
#     time: 1765934306
#     uncertainty: 30
#   }
#   departure {
#     delay: 0
#     time: 1765934324
#     uncertainty: 30
#   }
#   stop_id: "A20-2"
# }
# stop_time_update {
#   arrival {
#     delay: 0
#     time: 1765934575
#     uncertainty: 30
#   }
#   departure {
#     delay: 0
#     time: 1765934593
#     uncertainty: 30
#   }
#   stop_id: "A10-2"
# }
# stop_time_update {
#   arrival {
#     delay: 0
#     time: 1765934893
#     uncertainty: 30
#   }
#   departure {
#     delay: 0
#     time: 1765934923
#     uncertainty: 30
#   }
#   stop_id: "M10-1"
# }
# stop_time_update {
#   arrival {
#     delay: 0
#     time: 1765935307
#     uncertainty: 30
#   }
#   departure {
#     delay: 0
#     time: 1765935343
#     uncertainty: 30
#   }
#   stop_id: "M16-1"
# }
# stop_time_update {
#   arrival {
#     delay: 0
#     time: 1765935409
#     uncertainty: 30
#   }
#   departure {
#     delay: 0
#     time: 1765935439
#     uncertainty: 30
#   }
#   stop_id: "M20-1"
# }
# stop_time_update {
#   arrival {
#     delay: 0
#     time: 1765935511
#     uncertainty: 30
#   }
#   departure {
#     delay: 0
#     time: 1765935541
#     uncertainty: 30
#   }
#   stop_id: "M30-1"
# }
# stop_time_update {
#   arrival {
#     delay: 0
#     time: 1765935613
#     uncertainty: 30
#   }
#   departure {
#     delay: 0
#     time: 1765935637
#     uncertainty: 30
#   }
#   stop_id: "M40-1"
# }
# stop_time_update {
#   arrival {
#     delay: 0
#     time: 1765935757
#     uncertainty: 30
#   }
#   departure {
#     delay: 0
#     time: 1765935775
#     uncertainty: 30
#   }
#   stop_id: "M50-1"
# }
# stop_time_update {
#   arrival {
#     delay: 0
#     time: 1765935877
#     uncertainty: 30
#   }
#   departure {
#     delay: 0
#     time: 1765935895
#     uncertainty: 30
#   }
#   stop_id: "M60-1"
# }
# stop_time_update {
#   arrival {
#     delay: 0
#     time: 1765936045
#     uncertainty: 30
#   }
#   departure {
#     delay: 0
#     time: 1765936063
#     uncertainty: 30
#   }
#   stop_id: "M70-1"
# }
# stop_time_update {
#   arrival {
#     delay: 0
#     time: 1765936183
#     uncertainty: 30
#   }
#   departure {
#     delay: 0
#     time: 1765936201
#     uncertainty: 30
#   }
#   stop_id: "M80-1"
# }
# vehicle {
#   label: "3-door"
# }
#
# trip {
#   trip_id: "1771661"
#   schedule_relationship: SCHEDULED
# }
# stop_time_update {
#   arrival {
#     delay: 0
#     time: 1765931755
#     uncertainty: 30
#   }
#   departure {
#     delay: 0
#     time: 1765932725
#     uncertainty: 30
#   }
#   stop_id: "S50-1"
# }
# stop_time_update {
#   arrival {
#     delay: 0
#     time: 1765932953
#     uncertainty: 30
#   }
#   departure {
#     delay: 0
#     time: 1765932971
#     uncertainty: 30
#   }
#   stop_id: "S40-2"
# }
# stop_time_update {
#   arrival {
#     delay: 0
#     time: 1765933410
#     uncertainty: 30
#   }
#   departure {
#     delay: 0
#     time: 1765933428
#     uncertainty: 30
#   }
#   stop_id: "S20-2"
# }
# stop_time_update {
#   arrival {
#     delay: 0
#     time: 1765933786
#     uncertainty: 30
#   }
#   departure {
#     delay: 0
#     time: 1765933804
#     uncertainty: 30
#   }
#   stop_id: "A90-2"
# }
# stop_time_update {
#   arrival {
#     delay: 0
#     time: 1765934039
#     uncertainty: 30
#   }
#   departure {
#     delay: 0
#     time: 1765934057
#     uncertainty: 30
#   }
#   stop_id: "A80-2"
# }
# stop_time_update {
#   arrival {
#     delay: 0
#     time: 1765934343
#     uncertainty: 30
#   }
#   departure {
#     delay: 0
#     time: 1765934361
#     uncertainty: 30
#   }
#   stop_id: "A70-2"
# }
# stop_time_update {
#   arrival {
#     delay: 0
#     time: 1765934584
#     uncertainty: 30
#   }
#   departure {
#     delay: 0
#     time: 1765934602
#     uncertainty: 30
#   }
#   stop_id: "A60-2"
# }
# stop_time_update {
#   arrival {
#     delay: 0
#     time: 1765934825
#     uncertainty: 30
#   }
#   departure {
#     delay: 0
#     time: 1765934843
#     uncertainty: 30
#   }
#   stop_id: "A50-2"
# }
# stop_time_update {
#   arrival {
#     delay: 0
#     time: 1765935054
#     uncertainty: 30
#   }
#   departure {
#     delay: 0
#     time: 1765935072
#     uncertainty: 30
#   }
#   stop_id: "A40-2"
# }
# stop_time_update {
#   arrival {
#     delay: 0
#     time: 1765935307
#     uncertainty: 30
#   }
#   departure {
#     delay: 0
#     time: 1765935325
#     uncertainty: 30
#   }
#   stop_id: "A30-2"
# }
# stop_time_update {
#   arrival {
#     delay: 0
#     time: 1765935506
#     uncertainty: 30
#   }
#   departure {
#     delay: 0
#     time: 1765935524
#     uncertainty: 30
#   }
#   stop_id: "A20-2"
# }
# stop_time_update {
#   arrival {
#     delay: 0
#     time: 1765935775
#     uncertainty: 30
#   }
#   departure {
#     delay: 0
#     time: 1765935793
#     uncertainty: 30
#   }
#   stop_id: "A10-2"
# }
# stop_time_update {
#   arrival {
#     delay: 0
#     time: 1765936093
#     uncertainty: 30
#   }
#   departure {
#     delay: 0
#     time: 1765936123
#     uncertainty: 30
#   }
#   stop_id: "M10-1"
# }
# stop_time_update {
#   arrival {
#     delay: 0
#     time: 1765936507
#     uncertainty: 30
#   }
#   departure {
#     delay: 0
#     time: 1765936543
#     uncertainty: 30
#   }
#   stop_id: "M16-1"
# }
# stop_time_update {
#   arrival {
#     delay: 0
#     time: 1765936609
#     uncertainty: 30
#   }
#   departure {
#     delay: 0
#     time: 1765936639
#     uncertainty: 30
#   }
#   stop_id: "M20-1"
# }
# stop_time_update {
#   arrival {
#     delay: 0
#     time: 1765936711
#     uncertainty: 30
#   }
#   departure {
#     delay: 0
#     time: 1765936741
#     uncertainty: 30
#   }
#   stop_id: "M30-1"
# }
# stop_time_update {
#   arrival {
#     delay: 0
#     time: 1765936813
#     uncertainty: 30
#   }
#   departure {
#     delay: 0
#     time: 1765936837
#     uncertainty: 30
#   }
#   stop_id: "M40-1"
# }
# stop_time_update {
#   arrival {
#     delay: 0
#     time: 1765936957
#     uncertainty: 30
#   }
#   departure {
#     delay: 0
#     time: 1765936975
#     uncertainty: 30
#   }
#   stop_id: "M50-1"
# }
# stop_time_update {
#   arrival {
#     delay: 0
#     time: 1765937077
#     uncertainty: 30
#   }
#   departure {
#     delay: 0
#     time: 1765937095
#     uncertainty: 30
#   }
#   stop_id: "M60-1"
# }
# stop_time_update {
#   arrival {
#     delay: 0
#     time: 1765937245
#     uncertainty: 30
#   }
#   departure {
#     delay: 0
#     time: 1765937263
#     uncertainty: 30
#   }
#   stop_id: "M70-1"
# }
# stop_time_update {
#   arrival {
#     delay: 0
#     time: 1765937383
#     uncertainty: 30
#   }
#   departure {
#     delay: 0
#     time: 1765937401
#     uncertainty: 30
#   }
#   stop_id: "M80-1"
# }
# vehicle {
#   label: "3-door"
# }
#
# trip {
#   trip_id: "1771607"
#   schedule_relationship: SCHEDULED
# }
# stop_time_update {
#   arrival {
#     delay: 51
#     time: 1765931549
#     uncertainty: 30
#   }
#   departure {
#     delay: 51
#     time: 1765931567
#     uncertainty: 30
#   }
#   stop_id: "A80-1"
# }
# stop_time_update {
#   arrival {
#     delay: 0
#     time: 1765931761
#     uncertainty: 30
#   }
#   departure {
#     delay: 0
#     time: 1765931779
#     uncertainty: 30
#   }
#   stop_id: "A90-1"
# }
# stop_time_update {
#   arrival {
#     delay: 0
#     time: 1765932137
#     uncertainty: 30
#   }
#   departure {
#     delay: 0
#     time: 1765932155
#     uncertainty: 30
#   }
#   stop_id: "S20-1"
# }
# stop_time_update {
#   arrival {
#     delay: 0
#     time: 1765932598
#     uncertainty: 30
#   }
#   departure {
#     delay: 0
#     time: 1765932616
#     uncertainty: 30
#   }
#   stop_id: "S40-1"
# }
# vehicle {
#   label: "3-door"
# }
#
# trip {
#   trip_id: "1771662"
#   schedule_relationship: SCHEDULED
# }
# stop_time_update {
#   arrival {
#     delay: 0
#     time: 1765932880
#     uncertainty: 30
#   }
#   departure {
#     delay: 0
#     time: 1765933925
#     uncertainty: 30
#   }
#   stop_id: "S50-1"
# }
# stop_time_update {
#   arrival {
#     delay: 0
#     time: 1765934153
#     uncertainty: 30
#   }
#   departure {
#     delay: 0
#     time: 1765934171
#     uncertainty: 30
#   }
#   stop_id: "S40-2"
# }
# stop_time_update {
#   arrival {
#     delay: 0
#     time: 1765934610
#     uncertainty: 30
#   }
#   departure {
#     delay: 0
#     time: 1765934628
#     uncertainty: 30
#   }
#   stop_id: "S20-2"
# }
# stop_time_update {
#   arrival {
#     delay: 0
#     time: 1765934986
#     uncertainty: 30
#   }
#   departure {
#     delay: 0
#     time: 1765935004
#     uncertainty: 30
#   }
#   stop_id: "A90-2"
# }
# stop_time_update {
#   arrival {
#     delay: 0
#     time: 1765935239
#     uncertainty: 30
#   }
#   departure {
#     delay: 0
#     time: 1765935257
#     uncertainty: 30
#   }
#   stop_id: "A80-2"
# }
# stop_time_update {
#   arrival {
#     delay: 0
#     time: 1765935543
#     uncertainty: 30
#   }
#   departure {
#     delay: 0
#     time: 1765935561
#     uncertainty: 30
#   }
#   stop_id: "A70-2"
# }
# stop_time_update {
#   arrival {
#     delay: 0
#     time: 1765935784
#     uncertainty: 30
#   }
#   departure {
#     delay: 0
#     time: 1765935802
#     uncertainty: 30
#   }
#   stop_id: "A60-2"
# }
# stop_time_update {
#   arrival {
#     delay: 0
#     time: 1765936025
#     uncertainty: 30
#   }
#   departure {
#     delay: 0
#     time: 1765936043
#     uncertainty: 30
#   }
#   stop_id: "A50-2"
# }
# stop_time_update {
#   arrival {
#     delay: 0
#     time: 1765936254
#     uncertainty: 30
#   }
#   departure {
#     delay: 0
#     time: 1765936272
#     uncertainty: 30
#   }
#   stop_id: "A40-2"
# }
# stop_time_update {
#   arrival {
#     delay: 0
#     time: 1765936507
#     uncertainty: 30
#   }
#   departure {
#     delay: 0
#     time: 1765936525
#     uncertainty: 30
#   }
#   stop_id: "A30-2"
# }
# stop_time_update {
#   arrival {
#     delay: 0
#     time: 1765936706
#     uncertainty: 30
#   }
#   departure {
#     delay: 0
#     time: 1765936724
#     uncertainty: 30
#   }
#   stop_id: "A20-2"
# }
# stop_time_update {
#   arrival {
#     delay: 0
#     time: 1765936975
#     uncertainty: 30
#   }
#   departure {
#     delay: 0
#     time: 1765936993
#     uncertainty: 30
#   }
#   stop_id: "A10-2"
# }
# stop_time_update {
#   arrival {
#     delay: 0
#     time: 1765937293
#     uncertainty: 30
#   }
#   departure {
#     delay: 0
#     time: 1765937323
#     uncertainty: 30
#   }
#   stop_id: "M10-1"
# }
# stop_time_update {
#   arrival {
#     delay: 0
#     time: 1765937707
#     uncertainty: 30
#   }
#   departure {
#     delay: 0
#     time: 1765937743
#     uncertainty: 30
#   }
#   stop_id: "M16-1"
# }
# stop_time_update {
#   arrival {
#     delay: 0
#     time: 1765937809
#     uncertainty: 30
#   }
#   departure {
#     delay: 0
#     time: 1765937839
#     uncertainty: 30
#   }
#   stop_id: "M20-1"
# }
# stop_time_update {
#   arrival {
#     delay: 0
#     time: 1765937911
#     uncertainty: 30
#   }
#   departure {
#     delay: 0
#     time: 1765937941
#     uncertainty: 30
#   }
#   stop_id: "M30-1"
# }
# stop_time_update {
#   arrival {
#     delay: 0
#     time: 1765938013
#     uncertainty: 30
#   }
#   departure {
#     delay: 0
#     time: 1765938037
#     uncertainty: 30
#   }
#   stop_id: "M40-1"
# }
# stop_time_update {
#   arrival {
#     delay: 0
#     time: 1765938157
#     uncertainty: 30
#   }
#   departure {
#     delay: 0
#     time: 1765938175
#     uncertainty: 30
#   }
#   stop_id: "M50-1"
# }
# stop_time_update {
#   arrival {
#     delay: 0
#     time: 1765938277
#     uncertainty: 30
#   }
#   departure {
#     delay: 0
#     time: 1765938295
#     uncertainty: 30
#   }
#   stop_id: "M60-1"
# }
# stop_time_update {
#   arrival {
#     delay: 0
#     time: 1765938445
#     uncertainty: 30
#   }
#   departure {
#     delay: 0
#     time: 1765938463
#     uncertainty: 30
#   }
#   stop_id: "M70-1"
# }
# stop_time_update {
#   arrival {
#     delay: 0
#     time: 1765938583
#     uncertainty: 30
#   }
#   departure {
#     delay: 0
#     time: 1765938601
#     uncertainty: 30
#   }
#   stop_id: "M80-1"
# }
# vehicle {
#   label: "3-door"
# }
#
# trip {
#   trip_id: "1771608"
#   schedule_relationship: SCHEDULED
# }
# stop_time_update {
#   arrival {
#     delay: 77
#     time: 1765931703
#     uncertainty: 30
#   }
#   departure {
#     delay: 77
#     time: 1765931721
#     uncertainty: 30
#   }
#   stop_id: "A40-1"
# }
# stop_time_update {
#   arrival {
#     delay: 63
#     time: 1765931915
#     uncertainty: 30
#   }
#   departure {
#     delay: 63
#     time: 1765931951
#     uncertainty: 30
#   }
#   stop_id: "A50-1"
# }
# stop_time_update {
#   arrival {
#     delay: 35
#     time: 1765932157
#     uncertainty: 30
#   }
#   departure {
#     delay: 35
#     time: 1765932175
#     uncertainty: 30
#   }
#   stop_id: "A60-1"
# }
# stop_time_update {
#   arrival {
#     delay: 31
#     time: 1765932405
#     uncertainty: 30
#   }
#   departure {
#     delay: 31
#     time: 1765932423
#     uncertainty: 30
#   }
#   stop_id: "A70-1"
# }
# stop_time_update {
#   arrival {
#     delay: 0
#     time: 1765932699
#     uncertainty: 30
#   }
#   departure {
#     delay: 0
#     time: 1765932717
#     uncertainty: 30
#   }
#   stop_id: "A80-1"
# }
# stop_time_update {
#   arrival {
#     delay: 0
#     time: 1765932961
#     uncertainty: 30
#   }
#   departure {
#     delay: 0
#     time: 1765932979
#     uncertainty: 30
#   }
#   stop_id: "A90-1"
# }
# stop_time_update {
#   arrival {
#     delay: 0
#     time: 1765933337
#     uncertainty: 30
#   }
#   departure {
#     delay: 0
#     time: 1765933355
#     uncertainty: 30
#   }
#   stop_id: "S20-1"
# }
# stop_time_update {
#   arrival {
#     delay: 0
#     time: 1765933798
#     uncertainty: 30
#   }
#   departure {
#     delay: 0
#     time: 1765933816
#     uncertainty: 30
#   }
#   stop_id: "S40-1"
# }
# vehicle {
#   label: "3-door"
# }
#
# trip {
#   trip_id: "1771609"
#   schedule_relationship: SCHEDULED
# }
# stop_time_update {
#   arrival {
#     delay: 92
#     time: 1765931882
#     uncertainty: 30
#   }
#   departure {
#     delay: 92
#     time: 1765931905
#     uncertainty: 30
#   }
#   stop_id: "M10-2"
# }
# stop_time_update {
#   arrival {
#     delay: 63
#     time: 1765932199
#     uncertainty: 30
#   }
#   departure {
#     delay: 63
#     time: 1765932219
#     uncertainty: 30
#   }
#   stop_id: "A10-1"
# }
# stop_time_update {
#   arrival {
#     delay: 33
#     time: 1765932422
#     uncertainty: 30
#   }
#   departure {
#     delay: 33
#     time: 1765932440
#     uncertainty: 30
#   }
#   stop_id: "A20-1"
# }
# stop_time_update {
#   arrival {
#     delay: 33
#     time: 1765932614
#     uncertainty: 30
#   }
#   departure {
#     delay: 33
#     time: 1765932632
#     uncertainty: 30
#   }
#   stop_id: "A30-1"
# }
# stop_time_update {
#   arrival {
#     delay: 0
#     time: 1765932827
#     uncertainty: 30
#   }
#   departure {
#     delay: 0
#     time: 1765932845
#     uncertainty: 30
#   }
#   stop_id: "A40-1"
# }
# stop_time_update {
#   arrival {
#     delay: 0
#     time: 1765933053
#     uncertainty: 30
#   }
#   departure {
#     delay: 0
#     time: 1765933089
#     uncertainty: 30
#   }
#   stop_id: "A50-1"
# }
# stop_time_update {
#   arrival {
#     delay: 0
#     time: 1765933322
#     uncertainty: 30
#   }
#   departure {
#     delay: 0
#     time: 1765933340
#     uncertainty: 30
#   }
#   stop_id: "A60-1"
# }
# stop_time_update {
#   arrival {
#     delay: 0
#     time: 1765933575
#     uncertainty: 30
#   }
#   departure {
#     delay: 0
#     time: 1765933593
#     uncertainty: 30
#   }
#   stop_id: "A70-1"
# }
# stop_time_update {
#   arrival {
#     delay: 0
#     time: 1765933899
#     uncertainty: 30
#   }
#   departure {
#     delay: 0
#     time: 1765933917
#     uncertainty: 30
#   }
#   stop_id: "A80-1"
# }
# stop_time_update {
#   arrival {
#     delay: 0
#     time: 1765934161
#     uncertainty: 30
#   }
#   departure {
#     delay: 0
#     time: 1765934179
#     uncertainty: 30
#   }
#   stop_id: "A90-1"
# }
# stop_time_update {
#   arrival {
#     delay: 0
#     time: 1765934537
#     uncertainty: 30
#   }
#   departure {
#     delay: 0
#     time: 1765934555
#     uncertainty: 30
#   }
#   stop_id: "S20-1"
# }
# stop_time_update {
#   arrival {
#     delay: 0
#     time: 1765934998
#     uncertainty: 30
#   }
#   departure {
#     delay: 0
#     time: 1765935016
#     uncertainty: 30
#   }
#   stop_id: "S40-1"
# }
# vehicle {
#   label: "3-door"
# }
#
# trip {
#   trip_id: "1771610"
#   schedule_relationship: SCHEDULED
# }
# stop_time_update {
#   arrival {
#     delay: 0
#     time: 1765931259
#     uncertainty: 30
#   }
#   departure {
#     delay: 0
#     time: 1765931264
#     uncertainty: 30
#   }
#   stop_id: "M90-2"
# }
# stop_time_update {
#   arrival {
#     delay: 11
#     time: 1765931717
#     uncertainty: 30
#   }
#   departure {
#     delay: 11
#     time: 1765931735
#     uncertainty: 30
#   }
#   stop_id: "M80-2"
# }
# stop_time_update {
#   arrival {
#     delay: 8
#     time: 1765931852
#     uncertainty: 30
#   }
#   departure {
#     delay: 8
#     time: 1765931870
#     uncertainty: 30
#   }
#   stop_id: "M70-2"
# }
# stop_time_update {
#   arrival {
#     delay: 7
#     time: 1765932013
#     uncertainty: 30
#   }
#   departure {
#     delay: 7
#     time: 1765932031
#     uncertainty: 30
#   }
#   stop_id: "M60-2"
# }
# stop_time_update {
#   arrival {
#     delay: 2
#     time: 1765932128
#     uncertainty: 30
#   }
#   departure {
#     delay: 2
#     time: 1765932151
#     uncertainty: 30
#   }
#   stop_id: "M50-2"
# }
# stop_time_update {
#   arrival {
#     delay: 0
#     time: 1765932271
#     uncertainty: 30
#   }
#   departure {
#     delay: 0
#     time: 1765932295
#     uncertainty: 30
#   }
#   stop_id: "M40-2"
# }
# stop_time_update {
#   arrival {
#     delay: 0
#     time: 1765932367
#     uncertainty: 30
#   }
#   departure {
#     delay: 0
#     time: 1765932397
#     uncertainty: 30
#   }
#   stop_id: "M30-2"
# }
# stop_time_update {
#   arrival {
#     delay: 0
#     time: 1765932463
#     uncertainty: 30
#   }
#   departure {
#     delay: 0
#     time: 1765932493
#     uncertainty: 30
#   }
#   stop_id: "M20-2"
# }
# stop_time_update {
#   arrival {
#     delay: 0
#     time: 1765932559
#     uncertainty: 30
#   }
#   departure {
#     delay: 0
#     time: 1765932595
#     uncertainty: 30
#   }
#   stop_id: "M16-2"
# }
# stop_time_update {
#   arrival {
#     delay: 0
#     time: 1765932991
#     uncertainty: 30
#   }
#   departure {
#     delay: 0
#     time: 1765933021
#     uncertainty: 30
#   }
#   stop_id: "M10-2"
# }
# stop_time_update {
#   arrival {
#     delay: 0
#     time: 1765933337
#     uncertainty: 30
#   }
#   departure {
#     delay: 0
#     time: 1765933373
#     uncertainty: 30
#   }
#   stop_id: "A10-1"
# }
# stop_time_update {
#   arrival {
#     delay: 0
#     time: 1765933590
#     uncertainty: 30
#   }
#   departure {
#     delay: 0
#     time: 1765933608
#     uncertainty: 30
#   }
#   stop_id: "A20-1"
# }
# stop_time_update {
#   arrival {
#     delay: 0
#     time: 1765933782
#     uncertainty: 30
#   }
#   departure {
#     delay: 0
#     time: 1765933800
#     uncertainty: 30
#   }
#   stop_id: "A30-1"
# }
# stop_time_update {
#   arrival {
#     delay: 0
#     time: 1765934027
#     uncertainty: 30
#   }
#   departure {
#     delay: 0
#     time: 1765934045
#     uncertainty: 30
#   }
#   stop_id: "A40-1"
# }
# stop_time_update {
#   arrival {
#     delay: 0
#     time: 1765934253
#     uncertainty: 30
#   }
#   departure {
#     delay: 0
#     time: 1765934289
#     uncertainty: 30
#   }
#   stop_id: "A50-1"
# }
# stop_time_update {
#   arrival {
#     delay: 0
#     time: 1765934522
#     uncertainty: 30
#   }
#   departure {
#     delay: 0
#     time: 1765934540
#     uncertainty: 30
#   }
#   stop_id: "A60-1"
# }
# stop_time_update {
#   arrival {
#     delay: 0
#     time: 1765934775
#     uncertainty: 30
#   }
#   departure {
#     delay: 0
#     time: 1765934793
#     uncertainty: 30
#   }
#   stop_id: "A70-1"
# }
# stop_time_update {
#   arrival {
#     delay: 0
#     time: 1765935099
#     uncertainty: 30
#   }
#   departure {
#     delay: 0
#     time: 1765935117
#     uncertainty: 30
#   }
#   stop_id: "A80-1"
# }
# stop_time_update {
#   arrival {
#     delay: 0
#     time: 1765935361
#     uncertainty: 30
#   }
#   departure {
#     delay: 0
#     time: 1765935379
#     uncertainty: 30
#   }
#   stop_id: "A90-1"
# }
# stop_time_update {
#   arrival {
#     delay: 0
#     time: 1765935737
#     uncertainty: 30
#   }
#   departure {
#     delay: 0
#     time: 1765935755
#     uncertainty: 30
#   }
#   stop_id: "S20-1"
# }
# stop_time_update {
#   arrival {
#     delay: 0
#     time: 1765936198
#     uncertainty: 30
#   }
#   departure {
#     delay: 0
#     time: 1765936216
#     uncertainty: 30
#   }
#   stop_id: "S40-1"
# }
# vehicle {
#   label: "3-door"
# }
#
# trip {
#   trip_id: "1771611"
#   schedule_relationship: SCHEDULED
# }
# stop_time_update {
#   arrival {
#     delay: 0
#     time: 1765932463
#     uncertainty: 30
#   }
#   departure {
#     delay: 0
#     time: 1765932468
#     uncertainty: 30
#   }
#   stop_id: "M90-2"
# }
# stop_time_update {
#   arrival {
#     delay: 0
#     time: 1765932907
#     uncertainty: 30
#   }
#   departure {
#     delay: 0
#     time: 1765932925
#     uncertainty: 30
#   }
#   stop_id: "M80-2"
# }
# stop_time_update {
#   arrival {
#     delay: 0
#     time: 1765933045
#     uncertainty: 30
#   }
#   departure {
#     delay: 0
#     time: 1765933063
#     uncertainty: 30
#   }
#   stop_id: "M70-2"
# }
# stop_time_update {
#   arrival {
#     delay: 0
#     time: 1765933207
#     uncertainty: 30
#   }
#   departure {
#     delay: 0
#     time: 1765933225
#     uncertainty: 30
#   }
#   stop_id: "M60-2"
# }
# stop_time_update {
#   arrival {
#     delay: 0
#     time: 1765933327
#     uncertainty: 30
#   }
#   departure {
#     delay: 0
#     time: 1765933351
#     uncertainty: 30
#   }
#   stop_id: "M50-2"
# }
# stop_time_update {
#   arrival {
#     delay: 0
#     time: 1765933471
#     uncertainty: 30
#   }
#   departure {
#     delay: 0
#     time: 1765933495
#     uncertainty: 30
#   }
#   stop_id: "M40-2"
# }
# stop_time_update {
#   arrival {
#     delay: 0
#     time: 1765933567
#     uncertainty: 30
#   }
#   departure {
#     delay: 0
#     time: 1765933597
#     uncertainty: 30
#   }
#   stop_id: "M30-2"
# }
# stop_time_update {
#   arrival {
#     delay: 0
#     time: 1765933663
#     uncertainty: 30
#   }
#   departure {
#     delay: 0
#     time: 1765933693
#     uncertainty: 30
#   }
#   stop_id: "M20-2"
# }
# stop_time_update {
#   arrival {
#     delay: 0
#     time: 1765933759
#     uncertainty: 30
#   }
#   departure {
#     delay: 0
#     time: 1765933795
#     uncertainty: 30
#   }
#   stop_id: "M16-2"
# }
# stop_time_update {
#   arrival {
#     delay: 0
#     time: 1765934191
#     uncertainty: 30
#   }
#   departure {
#     delay: 0
#     time: 1765934221
#     uncertainty: 30
#   }
#   stop_id: "M10-2"
# }
# stop_time_update {
#   arrival {
#     delay: 0
#     time: 1765934537
#     uncertainty: 30
#   }
#   departure {
#     delay: 0
#     time: 1765934573
#     uncertainty: 30
#   }
#   stop_id: "A10-1"
# }
# stop_time_update {
#   arrival {
#     delay: 0
#     time: 1765934790
#     uncertainty: 30
#   }
#   departure {
#     delay: 0
#     time: 1765934808
#     uncertainty: 30
#   }
#   stop_id: "A20-1"
# }
# stop_time_update {
#   arrival {
#     delay: 0
#     time: 1765934982
#     uncertainty: 30
#   }
#   departure {
#     delay: 0
#     time: 1765935000
#     uncertainty: 30
#   }
#   stop_id: "A30-1"
# }
# stop_time_update {
#   arrival {
#     delay: 0
#     time: 1765935227
#     uncertainty: 30
#   }
#   departure {
#     delay: 0
#     time: 1765935245
#     uncertainty: 30
#   }
#   stop_id: "A40-1"
# }
# stop_time_update {
#   arrival {
#     delay: 0
#     time: 1765935453
#     uncertainty: 30
#   }
#   departure {
#     delay: 0
#     time: 1765935489
#     uncertainty: 30
#   }
#   stop_id: "A50-1"
# }
# stop_time_update {
#   arrival {
#     delay: 0
#     time: 1765935722
#     uncertainty: 30
#   }
#   departure {
#     delay: 0
#     time: 1765935740
#     uncertainty: 30
#   }
#   stop_id: "A60-1"
# }
# stop_time_update {
#   arrival {
#     delay: 0
#     time: 1765935975
#     uncertainty: 30
#   }
#   departure {
#     delay: 0
#     time: 1765935993
#     uncertainty: 30
#   }
#   stop_id: "A70-1"
# }
# stop_time_update {
#   arrival {
#     delay: 0
#     time: 1765936299
#     uncertainty: 30
#   }
#   departure {
#     delay: 0
#     time: 1765936317
#     uncertainty: 30
#   }
#   stop_id: "A80-1"
# }
# stop_time_update {
#   arrival {
#     delay: 0
#     time: 1765936561
#     uncertainty: 30
#   }
#   departure {
#     delay: 0
#     time: 1765936579
#     uncertainty: 30
#   }
#   stop_id: "A90-1"
# }
# stop_time_update {
#   arrival {
#     delay: 0
#     time: 1765936937
#     uncertainty: 30
#   }
#   departure {
#     delay: 0
#     time: 1765936955
#     uncertainty: 30
#   }
#   stop_id: "S20-1"
# }
# stop_time_update {
#   arrival {
#     delay: 0
#     time: 1765937398
#     uncertainty: 30
#   }
#   departure {
#     delay: 0
#     time: 1765937416
#     uncertainty: 30
#   }
#   stop_id: "S40-1"
# }
# vehicle {
#   label: "3-door"
# }
#
# trip {
#   trip_id: "1771657"
#   schedule_relationship: SCHEDULED
# }
# stop_time_update {
#   arrival {
#     delay: 139
#     time: 1765931845
#     uncertainty: 30
#   }
#   departure {
#     delay: 139
#     time: 1765931866
#     uncertainty: 30
#   }
#   stop_id: "M16-1"
# }
# stop_time_update {
#   arrival {
#     delay: 102
#     time: 1765931910
#     uncertainty: 30
#   }
#   departure {
#     delay: 102
#     time: 1765931935
#     uncertainty: 30
#   }
#   stop_id: "M20-1"
# }
# stop_time_update {
#   arrival {
#     delay: 95
#     time: 1765932006
#     uncertainty: 30
#   }
#   departure {
#     delay: 95
#     time: 1765932027
#     uncertainty: 30
#   }
#   stop_id: "M30-1"
# }
# stop_time_update {
#   arrival {
#     delay: 74
#     time: 1765932087
#     uncertainty: 30
#   }
#   departure {
#     delay: 74
#     time: 1765932108
#     uncertainty: 30
#   }
#   stop_id: "M40-1"
# }
# stop_time_update {
#   arrival {
#     delay: 66
#     time: 1765932222
#     uncertainty: 30
#   }
#   departure {
#     delay: 66
#     time: 1765932240
#     uncertainty: 30
#   }
#   stop_id: "M50-1"
# }
# stop_time_update {
#   arrival {
#     delay: 64
#     time: 1765932340
#     uncertainty: 30
#   }
#   departure {
#     delay: 64
#     time: 1765932358
#     uncertainty: 30
#   }
#   stop_id: "M60-1"
# }
# stop_time_update {
#   arrival {
#     delay: 62
#     time: 1765932506
#     uncertainty: 30
#   }
#   departure {
#     delay: 62
#     time: 1765932524
#     uncertainty: 30
#   }
#   stop_id: "M70-1"
# }
# stop_time_update {
#   arrival {
#     delay: 64
#     time: 1765932647
#     uncertainty: 30
#   }
#   departure {
#     delay: 64
#     time: 1765932665
#     uncertainty: 30
#   }
#   stop_id: "M80-1"
# }
# vehicle {
#   label: "3-door"
# }
#
# trip {
#   trip_id: "1771612"
#   schedule_relationship: SCHEDULED
# }
# stop_time_update {
#   arrival {
#     delay: 0
#     time: 1765933663
#     uncertainty: 30
#   }
#   departure {
#     delay: 0
#     time: 1765933668
#     uncertainty: 30
#   }
#   stop_id: "M90-2"
# }
# stop_time_update {
#   arrival {
#     delay: 0
#     time: 1765934107
#     uncertainty: 30
#   }
#   departure {
#     delay: 0
#     time: 1765934125
#     uncertainty: 30
#   }
#   stop_id: "M80-2"
# }
# stop_time_update {
#   arrival {
#     delay: 0
#     time: 1765934245
#     uncertainty: 30
#   }
#   departure {
#     delay: 0
#     time: 1765934263
#     uncertainty: 30
#   }
#   stop_id: "M70-2"
# }
# stop_time_update {
#   arrival {
#     delay: 0
#     time: 1765934407
#     uncertainty: 30
#   }
#   departure {
#     delay: 0
#     time: 1765934425
#     uncertainty: 30
#   }
#   stop_id: "M60-2"
# }
# stop_time_update {
#   arrival {
#     delay: 0
#     time: 1765934527
#     uncertainty: 30
#   }
#   departure {
#     delay: 0
#     time: 1765934551
#     uncertainty: 30
#   }
#   stop_id: "M50-2"
# }
# stop_time_update {
#   arrival {
#     delay: 0
#     time: 1765934671
#     uncertainty: 30
#   }
#   departure {
#     delay: 0
#     time: 1765934695
#     uncertainty: 30
#   }
#   stop_id: "M40-2"
# }
# stop_time_update {
#   arrival {
#     delay: 0
#     time: 1765934767
#     uncertainty: 30
#   }
#   departure {
#     delay: 0
#     time: 1765934797
#     uncertainty: 30
#   }
#   stop_id: "M30-2"
# }
# stop_time_update {
#   arrival {
#     delay: 0
#     time: 1765934863
#     uncertainty: 30
#   }
#   departure {
#     delay: 0
#     time: 1765934893
#     uncertainty: 30
#   }
#   stop_id: "M20-2"
# }
# stop_time_update {
#   arrival {
#     delay: 0
#     time: 1765934959
#     uncertainty: 30
#   }
#   departure {
#     delay: 0
#     time: 1765934995
#     uncertainty: 30
#   }
#   stop_id: "M16-2"
# }
# stop_time_update {
#   arrival {
#     delay: 0
#     time: 1765935391
#     uncertainty: 30
#   }
#   departure {
#     delay: 0
#     time: 1765935421
#     uncertainty: 30
#   }
#   stop_id: "M10-2"
# }
# stop_time_update {
#   arrival {
#     delay: 0
#     time: 1765935737
#     uncertainty: 30
#   }
#   departure {
#     delay: 0
#     time: 1765935773
#     uncertainty: 30
#   }
#   stop_id: "A10-1"
# }
# stop_time_update {
#   arrival {
#     delay: 0
#     time: 1765935990
#     uncertainty: 30
#   }
#   departure {
#     delay: 0
#     time: 1765936008
#     uncertainty: 30
#   }
#   stop_id: "A20-1"
# }
# stop_time_update {
#   arrival {
#     delay: 0
#     time: 1765936182
#     uncertainty: 30
#   }
#   departure {
#     delay: 0
#     time: 1765936200
#     uncertainty: 30
#   }
#   stop_id: "A30-1"
# }
# stop_time_update {
#   arrival {
#     delay: 0
#     time: 1765936427
#     uncertainty: 30
#   }
#   departure {
#     delay: 0
#     time: 1765936445
#     uncertainty: 30
#   }
#   stop_id: "A40-1"
# }
# stop_time_update {
#   arrival {
#     delay: 0
#     time: 1765936653
#     uncertainty: 30
#   }
#   departure {
#     delay: 0
#     time: 1765936689
#     uncertainty: 30
#   }
#   stop_id: "A50-1"
# }
# stop_time_update {
#   arrival {
#     delay: 0
#     time: 1765936922
#     uncertainty: 30
#   }
#   departure {
#     delay: 0
#     time: 1765936940
#     uncertainty: 30
#   }
#   stop_id: "A60-1"
# }
# stop_time_update {
#   arrival {
#     delay: 0
#     time: 1765937175
#     uncertainty: 30
#   }
#   departure {
#     delay: 0
#     time: 1765937193
#     uncertainty: 30
#   }
#   stop_id: "A70-1"
# }
# stop_time_update {
#   arrival {
#     delay: 0
#     time: 1765937499
#     uncertainty: 30
#   }
#   departure {
#     delay: 0
#     time: 1765937517
#     uncertainty: 30
#   }
#   stop_id: "A80-1"
# }
# stop_time_update {
#   arrival {
#     delay: 0
#     time: 1765937761
#     uncertainty: 30
#   }
#   departure {
#     delay: 0
#     time: 1765937779
#     uncertainty: 30
#   }
#   stop_id: "A90-1"
# }
# stop_time_update {
#   arrival {
#     delay: 0
#     time: 1765938137
#     uncertainty: 30
#   }
#   departure {
#     delay: 0
#     time: 1765938155
#     uncertainty: 30
#   }
#   stop_id: "S20-1"
# }
# stop_time_update {
#   arrival {
#     delay: 0
#     time: 1765938598
#     uncertainty: 30
#   }
#   departure {
#     delay: 0
#     time: 1765938616
#     uncertainty: 30
#   }
#   stop_id: "S40-1"
# }
# vehicle {
#   label: "3-door"
# }
#
# trip {
#   trip_id: "1771658"
#   schedule_relationship: SCHEDULED
# }
# stop_time_update {
#   arrival {
#     delay: 114
#     time: 1765931567
#     uncertainty: 30
#   }
#   departure {
#     delay: 114
#     time: 1765931585
#     uncertainty: 30
#   }
#   stop_id: "A40-2"
# }
# stop_time_update {
#   arrival {
#     delay: 80
#     time: 1765931787
#     uncertainty: 30
#   }
#   departure {
#     delay: 80
#     time: 1765931805
#     uncertainty: 30
#   }
#   stop_id: "A30-2"
# }
# stop_time_update {
#   arrival {
#     delay: 70
#     time: 1765931976
#     uncertainty: 30
#   }
#   departure {
#     delay: 70
#     time: 1765931994
#     uncertainty: 30
#   }
#   stop_id: "A20-2"
# }
# stop_time_update {
#   arrival {
#     delay: 67
#     time: 1765932241
#     uncertainty: 30
#   }
#   departure {
#     delay: 67
#     time: 1765932259
#     uncertainty: 30
#   }
#   stop_id: "A10-2"
# }
# stop_time_update {
#   arrival {
#     delay: 41
#     time: 1765932534
#     uncertainty: 30
#   }
#   departure {
#     delay: 41
#     time: 1765932558
#     uncertainty: 30
#   }
#   stop_id: "M10-1"
# }
# stop_time_update {
#   arrival {
#     delay: 30
#     time: 1765932937
#     uncertainty: 30
#   }
#   departure {
#     delay: 30
#     time: 1765932958
#     uncertainty: 30
#   }
#   stop_id: "M16-1"
# }
# stop_time_update {
#   arrival {
#     delay: 32
#     time: 1765933040
#     uncertainty: 30
#   }
#   departure {
#     delay: 32
#     time: 1765933064
#     uncertainty: 30
#   }
#   stop_id: "M20-1"
# }
# stop_time_update {
#   arrival {
#     delay: 0
#     time: 1765933111
#     uncertainty: 30
#   }
#   departure {
#     delay: 0
#     time: 1765933132
#     uncertainty: 30
#   }
#   stop_id: "M30-1"
# }
# stop_time_update {
#   arrival {
#     delay: 0
#     time: 1765933213
#     uncertainty: 30
#   }
#   departure {
#     delay: 0
#     time: 1765933234
#     uncertainty: 30
#   }
#   stop_id: "M40-1"
# }
# stop_time_update {
#   arrival {
#     delay: 0
#     time: 1765933357
#     uncertainty: 30
#   }
#   departure {
#     delay: 0
#     time: 1765933375
#     uncertainty: 30
#   }
#   stop_id: "M50-1"
# }
# stop_time_update {
#   arrival {
#     delay: 0
#     time: 1765933477
#     uncertainty: 30
#   }
#   departure {
#     delay: 0
#     time: 1765933495
#     uncertainty: 30
#   }
#   stop_id: "M60-1"
# }
# stop_time_update {
#   arrival {
#     delay: 0
#     time: 1765933645
#     uncertainty: 30
#   }
#   departure {
#     delay: 0
#     time: 1765933663
#     uncertainty: 30
#   }
#   stop_id: "M70-1"
# }
# stop_time_update {
#   arrival {
#     delay: 0
#     time: 1765933783
#     uncertainty: 30
#   }
#   departure {
#     delay: 0
#     time: 1765933801
#     uncertainty: 30
#   }
#   stop_id: "M80-1"
# }
# vehicle {
#   label: "3-door"
# }
#
# trip {
#   trip_id: "1771659"
#   schedule_relationship: SCHEDULED
# }
# stop_time_update {
#   arrival {
#     delay: 149
#     time: 1765931534
#     uncertainty: 30
#   }
#   departure {
#     delay: 149
#     time: 1765931552
#     uncertainty: 30
#   }
#   stop_id: "A90-2"
# }
# stop_time_update {
#   arrival {
#     delay: 90
#     time: 1765931729
#     uncertainty: 30
#   }
#   departure {
#     delay: 90
#     time: 1765931747
#     uncertainty: 30
#   }
#   stop_id: "A80-2"
# }
# stop_time_update {
#   arrival {
#     delay: 82
#     time: 1765932025
#     uncertainty: 30
#   }
#   departure {
#     delay: 82
#     time: 1765932043
#     uncertainty: 30
#   }
#   stop_id: "A70-2"
# }
# stop_time_update {
#   arrival {
#     delay: 71
#     time: 1765932255
#     uncertainty: 30
#   }
#   departure {
#     delay: 71
#     time: 1765932273
#     uncertainty: 30
#   }
#   stop_id: "A60-2"
# }
# stop_time_update {
#   arrival {
#     delay: 68
#     time: 1765932493
#     uncertainty: 30
#   }
#   departure {
#     delay: 68
#     time: 1765932511
#     uncertainty: 30
#   }
#   stop_id: "A50-2"
# }
# stop_time_update {
#   arrival {
#     delay: 53
#     time: 1765932707
#     uncertainty: 30
#   }
#   departure {
#     delay: 53
#     time: 1765932725
#     uncertainty: 30
#   }
#   stop_id: "A40-2"
# }
# stop_time_update {
#   arrival {
#     delay: 39
#     time: 1765932946
#     uncertainty: 30
#   }
#   departure {
#     delay: 39
#     time: 1765932964
#     uncertainty: 30
#   }
#   stop_id: "A30-2"
# }
# stop_time_update {
#   arrival {
#     delay: 31
#     time: 1765933136
#     uncertainty: 30
#   }
#   departure {
#     delay: 31
#     time: 1765933154
#     uncertainty: 30
#   }
#   stop_id: "A20-2"
# }
# stop_time_update {
#   arrival {
#     delay: 30
#     time: 1765933405
#     uncertainty: 30
#   }
#   departure {
#     delay: 30
#     time: 1765933423
#     uncertainty: 30
#   }
#   stop_id: "A10-2"
# }
# stop_time_update {
#   arrival {
#     delay: 0
#     time: 1765933693
#     uncertainty: 30
#   }
#   departure {
#     delay: 0
#     time: 1765933715
#     uncertainty: 30
#   }
#   stop_id: "M10-1"
# }
# stop_time_update {
#   arrival {
#     delay: 0
#     time: 1765934107
#     uncertainty: 30
#   }
#   departure {
#     delay: 0
#     time: 1765934138
#     uncertainty: 30
#   }
#   stop_id: "M16-1"
# }
# stop_time_update {
#   arrival {
#     delay: 0
#     time: 1765934209
#     uncertainty: 30
#   }
#   departure {
#     delay: 0
#     time: 1765934239
#     uncertainty: 30
#   }
#   stop_id: "M20-1"
# }
# stop_time_update {
#   arrival {
#     delay: 0
#     time: 1765934311
#     uncertainty: 30
#   }
#   departure {
#     delay: 0
#     time: 1765934341
#     uncertainty: 30
#   }
#   stop_id: "M30-1"
# }
# stop_time_update {
#   arrival {
#     delay: 0
#     time: 1765934413
#     uncertainty: 30
#   }
#   departure {
#     delay: 0
#     time: 1765934437
#     uncertainty: 30
#   }
#   stop_id: "M40-1"
# }
# stop_time_update {
#   arrival {
#     delay: 0
#     time: 1765934557
#     uncertainty: 30
#   }
#   departure {
#     delay: 0
#     time: 1765934575
#     uncertainty: 30
#   }
#   stop_id: "M50-1"
# }
# stop_time_update {
#   arrival {
#     delay: 0
#     time: 1765934677
#     uncertainty: 30
#   }
#   departure {
#     delay: 0
#     time: 1765934695
#     uncertainty: 30
#   }
#   stop_id: "M60-1"
# }
# stop_time_update {
#   arrival {
#     delay: 0
#     time: 1765934845
#     uncertainty: 30
#   }
#   departure {
#     delay: 0
#     time: 1765934863
#     uncertainty: 30
#   }
#   stop_id: "M70-1"
# }
# stop_time_update {
#   arrival {
#     delay: 0
#     time: 1765934983
#     uncertainty: 30
#   }
#   departure {
#     delay: 0
#     time: 1765935001
#     uncertainty: 30
#   }
#   stop_id: "M80-1"
# }
# vehicle {
#   label: "3-door"
# }
#
# trip {
#   trip_id: "1771704"
#   schedule_relationship: SCHEDULED
# }
# stop_time_update {
#   arrival {
#     delay: 32
#     time: 1765931642
#     uncertainty: 30
#   }
#   departure {
#     delay: 32
#     time: 1765931660
#     uncertainty: 30
#   }
#   stop_id: "S20-2"
# }
# stop_time_update {
#   arrival {
#     delay: 0
#     time: 1765931986
#     uncertainty: 30
#   }
#   departure {
#     delay: 0
#     time: 1765932004
#     uncertainty: 30
#   }
#   stop_id: "A90-2"
# }
# stop_time_update {
#   arrival {
#     delay: 0
#     time: 1765932239
#     uncertainty: 30
#   }
#   departure {
#     delay: 0
#     time: 1765932257
#     uncertainty: 30
#   }
#   stop_id: "A80-2"
# }
# stop_time_update {
#   arrival {
#     delay: 0
#     time: 1765932543
#     uncertainty: 30
#   }
#   departure {
#     delay: 0
#     time: 1765932561
#     uncertainty: 30
#   }
#   stop_id: "A70-2"
# }
# stop_time_update {
#   arrival {
#     delay: 0
#     time: 1765932784
#     uncertainty: 30
#   }
#   departure {
#     delay: 0
#     time: 1765932802
#     uncertainty: 30
#   }
#   stop_id: "A60-2"
# }
# stop_time_update {
#   arrival {
#     delay: 0
#     time: 1765933025
#     uncertainty: 30
#   }
#   departure {
#     delay: 0
#     time: 1765933043
#     uncertainty: 30
#   }
#   stop_id: "A50-2"
# }
# stop_time_update {
#   arrival {
#     delay: 0
#     time: 1765933254
#     uncertainty: 30
#   }
#   departure {
#     delay: 0
#     time: 1765933272
#     uncertainty: 30
#   }
#   stop_id: "A40-2"
# }
# stop_time_update {
#   arrival {
#     delay: 0
#     time: 1765933507
#     uncertainty: 30
#   }
#   departure {
#     delay: 0
#     time: 1765933525
#     uncertainty: 30
#   }
#   stop_id: "A30-2"
# }
# stop_time_update {
#   arrival {
#     delay: 0
#     time: 1765933706
#     uncertainty: 30
#   }
#   departure {
#     delay: 0
#     time: 1765933724
#     uncertainty: 30
#   }
#   stop_id: "A20-2"
# }
# stop_time_update {
#   arrival {
#     delay: 0
#     time: 1765933975
#     uncertainty: 30
#   }
#   departure {
#     delay: 0
#     time: 1765933993
#     uncertainty: 30
#   }
#   stop_id: "A10-2"
# }
# stop_time_update {
#   arrival {
#     delay: 0
#     time: 1765934149
#     uncertainty: 30
#   }
#   departure {
#     delay: 0
#     time: 1765934173
#     uncertainty: 30
#   }
#   stop_id: "K10-1"
# }
# stop_time_update {
#   arrival {
#     delay: 0
#     time: 1765934233
#     uncertainty: 30
#   }
#   departure {
#     delay: 0
#     time: 1765934287
#     uncertainty: 30
#   }
#   stop_id: "K20-1"
# }
# stop_time_update {
#   arrival {
#     delay: 0
#     time: 1765934478
#     uncertainty: 30
#   }
#   departure {
#     delay: 0
#     time: 1765934520
#     uncertainty: 30
#   }
#   stop_id: "K30-1"
# }
# stop_time_update {
#   arrival {
#     delay: 0
#     time: 1765934694
#     uncertainty: 30
#   }
#   departure {
#     delay: 0
#     time: 1765934712
#     uncertainty: 30
#   }
#   stop_id: "R10-1"
# }
# stop_time_update {
#   arrival {
#     delay: 0
#     time: 1765934832
#     uncertainty: 30
#   }
#   departure {
#     delay: 0
#     time: 1765934856
#     uncertainty: 30
#   }
#   stop_id: "R20-1"
# }
# stop_time_update {
#   arrival {
#     delay: 0
#     time: 1765934976
#     uncertainty: 30
#   }
#   departure {
#     delay: 0
#     time: 1765934994
#     uncertainty: 30
#   }
#   stop_id: "R30-1"
# }
# stop_time_update {
#   arrival {
#     delay: 0
#     time: 1765935168
#     uncertainty: 30
#   }
#   departure {
#     delay: 0
#     time: 1765935186
#     uncertainty: 30
#   }
#   stop_id: "R40-1"
# }
# stop_time_update {
#   arrival {
#     delay: 0
#     time: 1765935349
#     uncertainty: 30
#   }
#   departure {
#     delay: 0
#     time: 1765935397
#     uncertainty: 30
#   }
#   stop_id: "R50-1"
# }
# vehicle {
#   label: "3-door"
# }
#
# trip {
#   trip_id: "1771705"
#   schedule_relationship: SCHEDULED
# }
# stop_time_update {
#   arrival {
#     delay: 0
#     time: 1765931350
#     uncertainty: 30
#   }
#   departure {
#     delay: 0
#     time: 1765932112
#     uncertainty: 30
#   }
#   stop_id: "S50-2"
# }
# stop_time_update {
#   arrival {
#     delay: 0
#     time: 1765932353
#     uncertainty: 30
#   }
#   departure {
#     delay: 0
#     time: 1765932371
#     uncertainty: 30
#   }
#   stop_id: "S40-2"
# }
# stop_time_update {
#   arrival {
#     delay: 0
#     time: 1765932810
#     uncertainty: 30
#   }
#   departure {
#     delay: 0
#     time: 1765932828
#     uncertainty: 30
#   }
#   stop_id: "S20-2"
# }
# stop_time_update {
#   arrival {
#     delay: 0
#     time: 1765933186
#     uncertainty: 30
#   }
#   departure {
#     delay: 0
#     time: 1765933204
#     uncertainty: 30
#   }
#   stop_id: "A90-2"
# }
# stop_time_update {
#   arrival {
#     delay: 0
#     time: 1765933439
#     uncertainty: 30
#   }
#   departure {
#     delay: 0
#     time: 1765933457
#     uncertainty: 30
#   }
#   stop_id: "A80-2"
# }
# stop_time_update {
#   arrival {
#     delay: 0
#     time: 1765933743
#     uncertainty: 30
#   }
#   departure {
#     delay: 0
#     time: 1765933761
#     uncertainty: 30
#   }
#   stop_id: "A70-2"
# }
# stop_time_update {
#   arrival {
#     delay: 0
#     time: 1765933984
#     uncertainty: 30
#   }
#   departure {
#     delay: 0
#     time: 1765934002
#     uncertainty: 30
#   }
#   stop_id: "A60-2"
# }
# stop_time_update {
#   arrival {
#     delay: 0
#     time: 1765934225
#     uncertainty: 30
#   }
#   departure {
#     delay: 0
#     time: 1765934243
#     uncertainty: 30
#   }
#   stop_id: "A50-2"
# }
# stop_time_update {
#   arrival {
#     delay: 0
#     time: 1765934454
#     uncertainty: 30
#   }
#   departure {
#     delay: 0
#     time: 1765934472
#     uncertainty: 30
#   }
#   stop_id: "A40-2"
# }
# stop_time_update {
#   arrival {
#     delay: 0
#     time: 1765934707
#     uncertainty: 30
#   }
#   departure {
#     delay: 0
#     time: 1765934725
#     uncertainty: 30
#   }
#   stop_id: "A30-2"
# }
# stop_time_update {
#   arrival {
#     delay: 0
#     time: 1765934906
#     uncertainty: 30
#   }
#   departure {
#     delay: 0
#     time: 1765934924
#     uncertainty: 30
#   }
#   stop_id: "A20-2"
# }
# stop_time_update {
#   arrival {
#     delay: 0
#     time: 1765935175
#     uncertainty: 30
#   }
#   departure {
#     delay: 0
#     time: 1765935193
#     uncertainty: 30
#   }
#   stop_id: "A10-2"
# }
# stop_time_update {
#   arrival {
#     delay: 0
#     time: 1765935349
#     uncertainty: 30
#   }
#   departure {
#     delay: 0
#     time: 1765935373
#     uncertainty: 30
#   }
#   stop_id: "K10-1"
# }
# stop_time_update {
#   arrival {
#     delay: 0
#     time: 1765935433
#     uncertainty: 30
#   }
#   departure {
#     delay: 0
#     time: 1765935487
#     uncertainty: 30
#   }
#   stop_id: "K20-1"
# }
# stop_time_update {
#   arrival {
#     delay: 0
#     time: 1765935678
#     uncertainty: 30
#   }
#   departure {
#     delay: 0
#     time: 1765935720
#     uncertainty: 30
#   }
#   stop_id: "K30-1"
# }
# stop_time_update {
#   arrival {
#     delay: 0
#     time: 1765935894
#     uncertainty: 30
#   }
#   departure {
#     delay: 0
#     time: 1765935912
#     uncertainty: 30
#   }
#   stop_id: "R10-1"
# }
# stop_time_update {
#   arrival {
#     delay: 0
#     time: 1765936032
#     uncertainty: 30
#   }
#   departure {
#     delay: 0
#     time: 1765936056
#     uncertainty: 30
#   }
#   stop_id: "R20-1"
# }
# stop_time_update {
#   arrival {
#     delay: 0
#     time: 1765936176
#     uncertainty: 30
#   }
#   departure {
#     delay: 0
#     time: 1765936194
#     uncertainty: 30
#   }
#   stop_id: "R30-1"
# }
# stop_time_update {
#   arrival {
#     delay: 0
#     time: 1765936368
#     uncertainty: 30
#   }
#   departure {
#     delay: 0
#     time: 1765936386
#     uncertainty: 30
#   }
#   stop_id: "R40-1"
# }
# stop_time_update {
#   arrival {
#     delay: 0
#     time: 1765936549
#     uncertainty: 30
#   }
#   departure {
#     delay: 0
#     time: 1765936597
#     uncertainty: 30
#   }
#   stop_id: "R50-1"
# }
# vehicle {
#   label: "3-door"
# }
#
# trip {
#   trip_id: "1771888"
#   schedule_relationship: SCHEDULED
# }
# stop_time_update {
#   arrival {
#     delay: 23
#     time: 1765931626
#     uncertainty: 30
#   }
#   departure {
#     delay: 23
#     time: 1765931644
#     uncertainty: 30
#   }
#   stop_id: "S20-1"
# }
# stop_time_update {
#   arrival {
#     delay: 0
#     time: 1765932064
#     uncertainty: 30
#   }
#   departure {
#     delay: 0
#     time: 1765932082
#     uncertainty: 30
#   }
#   stop_id: "S40-1"
# }
# vehicle {
#   label: "3-door"
# }
#
# trip {
#   trip_id: "1771706"
#   schedule_relationship: SCHEDULED
# }
# stop_time_update {
#   arrival {
#     delay: 0
#     time: 1765932352
#     uncertainty: 30
#   }
#   departure {
#     delay: 0
#     time: 1765933312
#     uncertainty: 30
#   }
#   stop_id: "S50-2"
# }
# stop_time_update {
#   arrival {
#     delay: 0
#     time: 1765933553
#     uncertainty: 30
#   }
#   departure {
#     delay: 0
#     time: 1765933571
#     uncertainty: 30
#   }
#   stop_id: "S40-2"
# }
# stop_time_update {
#   arrival {
#     delay: 0
#     time: 1765934010
#     uncertainty: 30
#   }
#   departure {
#     delay: 0
#     time: 1765934028
#     uncertainty: 30
#   }
#   stop_id: "S20-2"
# }
# stop_time_update {
#   arrival {
#     delay: 0
#     time: 1765934386
#     uncertainty: 30
#   }
#   departure {
#     delay: 0
#     time: 1765934404
#     uncertainty: 30
#   }
#   stop_id: "A90-2"
# }
# stop_time_update {
#   arrival {
#     delay: 0
#     time: 1765934639
#     uncertainty: 30
#   }
#   departure {
#     delay: 0
#     time: 1765934657
#     uncertainty: 30
#   }
#   stop_id: "A80-2"
# }
# stop_time_update {
#   arrival {
#     delay: 0
#     time: 1765934943
#     uncertainty: 30
#   }
#   departure {
#     delay: 0
#     time: 1765934961
#     uncertainty: 30
#   }
#   stop_id: "A70-2"
# }
# stop_time_update {
#   arrival {
#     delay: 0
#     time: 1765935184
#     uncertainty: 30
#   }
#   departure {
#     delay: 0
#     time: 1765935202
#     uncertainty: 30
#   }
#   stop_id: "A60-2"
# }
# stop_time_update {
#   arrival {
#     delay: 0
#     time: 1765935425
#     uncertainty: 30
#   }
#   departure {
#     delay: 0
#     time: 1765935443
#     uncertainty: 30
#   }
#   stop_id: "A50-2"
# }
# stop_time_update {
#   arrival {
#     delay: 0
#     time: 1765935654
#     uncertainty: 30
#   }
#   departure {
#     delay: 0
#     time: 1765935672
#     uncertainty: 30
#   }
#   stop_id: "A40-2"
# }
# stop_time_update {
#   arrival {
#     delay: 0
#     time: 1765935907
#     uncertainty: 30
#   }
#   departure {
#     delay: 0
#     time: 1765935925
#     uncertainty: 30
#   }
#   stop_id: "A30-2"
# }
# stop_time_update {
#   arrival {
#     delay: 0
#     time: 1765936106
#     uncertainty: 30
#   }
#   departure {
#     delay: 0
#     time: 1765936124
#     uncertainty: 30
#   }
#   stop_id: "A20-2"
# }
# stop_time_update {
#   arrival {
#     delay: 0
#     time: 1765936375
#     uncertainty: 30
#   }
#   departure {
#     delay: 0
#     time: 1765936393
#     uncertainty: 30
#   }
#   stop_id: "A10-2"
# }
# stop_time_update {
#   arrival {
#     delay: 0
#     time: 1765936549
#     uncertainty: 30
#   }
#   departure {
#     delay: 0
#     time: 1765936573
#     uncertainty: 30
#   }
#   stop_id: "K10-1"
# }
# stop_time_update {
#   arrival {
#     delay: 0
#     time: 1765936633
#     uncertainty: 30
#   }
#   departure {
#     delay: 0
#     time: 1765936687
#     uncertainty: 30
#   }
#   stop_id: "K20-1"
# }
# stop_time_update {
#   arrival {
#     delay: 0
#     time: 1765936878
#     uncertainty: 30
#   }
#   departure {
#     delay: 0
#     time: 1765936920
#     uncertainty: 30
#   }
#   stop_id: "K30-1"
# }
# stop_time_update {
#   arrival {
#     delay: 0
#     time: 1765937094
#     uncertainty: 30
#   }
#   departure {
#     delay: 0
#     time: 1765937112
#     uncertainty: 30
#   }
#   stop_id: "R10-1"
# }
# stop_time_update {
#   arrival {
#     delay: 0
#     time: 1765937232
#     uncertainty: 30
#   }
#   departure {
#     delay: 0
#     time: 1765937256
#     uncertainty: 30
#   }
#   stop_id: "R20-1"
# }
# stop_time_update {
#   arrival {
#     delay: 0
#     time: 1765937376
#     uncertainty: 30
#   }
#   departure {
#     delay: 0
#     time: 1765937394
#     uncertainty: 30
#   }
#   stop_id: "R30-1"
# }
# stop_time_update {
#   arrival {
#     delay: 0
#     time: 1765937568
#     uncertainty: 30
#   }
#   departure {
#     delay: 0
#     time: 1765937586
#     uncertainty: 30
#   }
#   stop_id: "R40-1"
# }
# stop_time_update {
#   arrival {
#     delay: 0
#     time: 1765937749
#     uncertainty: 30
#   }
#   departure {
#     delay: 0
#     time: 1765937797
#     uncertainty: 30
#   }
#   stop_id: "R50-1"
# }
# vehicle {
#   label: "3-door"
# }
#
# trip {
#   trip_id: "1771889"
#   schedule_relationship: SCHEDULED
# }
# stop_time_update {
#   arrival {
#     delay: 36
#     time: 1765931624
#     uncertainty: 30
#   }
#   departure {
#     delay: 36
#     time: 1765931642
#     uncertainty: 30
#   }
#   stop_id: "A60-1"
# }
# stop_time_update {
#   arrival {
#     delay: 0
#     time: 1765931841
#     uncertainty: 30
#   }
#   departure {
#     delay: 0
#     time: 1765931859
#     uncertainty: 30
#   }
#   stop_id: "A70-1"
# }
# stop_time_update {
#   arrival {
#     delay: 0
#     time: 1765932165
#     uncertainty: 30
#   }
#   departure {
#     delay: 0
#     time: 1765932183
#     uncertainty: 30
#   }
#   stop_id: "A80-1"
# }
# stop_time_update {
#   arrival {
#     delay: 0
#     time: 1765932427
#     uncertainty: 30
#   }
#   departure {
#     delay: 0
#     time: 1765932445
#     uncertainty: 30
#   }
#   stop_id: "A90-1"
# }
# stop_time_update {
#   arrival {
#     delay: 0
#     time: 1765932803
#     uncertainty: 30
#   }
#   departure {
#     delay: 0
#     time: 1765932821
#     uncertainty: 30
#   }
#   stop_id: "S20-1"
# }
# stop_time_update {
#   arrival {
#     delay: 0
#     time: 1765933264
#     uncertainty: 30
#   }
# ...
#     delay: 0
#     time: 1765933758
#     uncertainty: 30
#   }
#   departure {
#     delay: 0
#     time: 1765933776
#     uncertainty: 30
#   }
#   stop_id: "L10-2"
# }
# stop_time_update {
#   arrival {
#     delay: 0
#     time: 1765934045
#     uncertainty: 30
#   }
#   departure {
#     delay: 0
#     time: 1765934063
#     uncertainty: 30
#   }
#   stop_id: "A50-2"
# }
# stop_time_update {
#   arrival {
#     delay: 0
#     time: 1765934274
#     uncertainty: 30
#   }
#   departure {
#     delay: 0
#     time: 1765934292
#     uncertainty: 30
#   }
#   stop_id: "A40-2"
# }
# stop_time_update {
#   arrival {
#     delay: 0
#     time: 1765934527
#     uncertainty: 30
#   }
#   departure {
#     delay: 0
#     time: 1765934545
#     uncertainty: 30
#   }
#   stop_id: "A30-2"
# }
# stop_time_update {
#   arrival {
#     delay: 0
#     time: 1765934726
#     uncertainty: 30
#   }
#   departure {
#     delay: 0
#     time: 1765934744
#     uncertainty: 30
#   }
#   stop_id: "A20-2"
# }
# stop_time_update {
#   arrival {
#     delay: 0
#     time: 1765934995
#     uncertainty: 30
#   }
#   departure {
#     delay: 0
#     time: 1765935013
#     uncertainty: 30
#   }
#   stop_id: "A10-2"
# }
# stop_time_update {
#   arrival {
#     delay: 0
#     time: 1765935313
#     uncertainty: 30
#   }
#   departure {
#     delay: 0
#     time: 1765935343
#     uncertainty: 30
#   }
#   stop_id: "M10-1"
# }
# stop_time_update {
#   arrival {
#     delay: 0
#     time: 1765935727
#     uncertainty: 30
#   }
#   departure {
#     delay: 0
#     time: 1765935763
#     uncertainty: 30
#   }
#   stop_id: "M16-1"
# }
# stop_time_update {
#   arrival {
#     delay: 0
#     time: 1765935829
#     uncertainty: 30
#   }
#   departure {
#     delay: 0
#     time: 1765935859
#     uncertainty: 30
#   }
#   stop_id: "M20-1"
# }
# stop_time_update {
#   arrival {
#     delay: 0
#     time: 1765935931
#     uncertainty: 30
#   }
#   departure {
#     delay: 0
#     time: 1765935961
#     uncertainty: 30
#   }
#   stop_id: "M30-1"
# }
# stop_time_update {
#   arrival {
#     delay: 0
#     time: 1765936033
#     uncertainty: 30
#   }
#   departure {
#     delay: 0
#     time: 1765936057
#     uncertainty: 30
#   }
#   stop_id: "M40-1"
# }
# stop_time_update {
#   arrival {
#     delay: 0
#     time: 1765936177
#     uncertainty: 30
#   }
#   departure {
#     delay: 0
#     time: 1765936195
#     uncertainty: 30
#   }
#   stop_id: "M50-1"
# }
# stop_time_update {
#   arrival {
#     delay: 0
#     time: 1765936297
#     uncertainty: 30
#   }
#   departure {
#     delay: 0
#     time: 1765936315
#     uncertainty: 30
#   }
#   stop_id: "M60-1"
# }
# stop_time_update {
#   arrival {
#     delay: 0
#     time: 1765936465
#     uncertainty: 30
#   }
#   departure {
#     delay: 0
#     time: 1765936483
#     uncertainty: 30
#   }
#   stop_id: "M70-1"
# }
# stop_time_update {
#   arrival {
#     delay: 0
#     time: 1765936603
#     uncertainty: 30
#   }
#   departure {
#     delay: 0
#     time: 1765936621
#     uncertainty: 30
#   }
#   stop_id: "M80-1"
# }
# vehicle {
#   label: "2-door"
# }
#
# trip {
#   trip_id: "1771490"
#   schedule_relationship: SCHEDULED
# }
# stop_time_update {
#   arrival {
#     delay: 85
#     time: 1765931513
#     uncertainty: 30
#   }
#   departure {
#     delay: 85
#     time: 1765931531
#     uncertainty: 30
#   }
#   stop_id: "A40-1"
# }
# stop_time_update {
#   arrival {
#     delay: 66
#     time: 1765931720
#     uncertainty: 30
#   }
#   departure {
#     delay: 66
#     time: 1765931756
#     uncertainty: 30
#   }
#   stop_id: "A50-1"
# }
# stop_time_update {
#   arrival {
#     delay: 32
#     time: 1765931968
#     uncertainty: 30
#   }
#   departure {
#     delay: 32
#     time: 1765931986
#     uncertainty: 30
#   }
#   stop_id: "L10-1"
# }
# stop_time_update {
#   arrival {
#     delay: 33
#     time: 1765932547
#     uncertainty: 30
#   }
#   departure {
#     delay: 33
#     time: 1765932565
#     uncertainty: 30
#   }
#   stop_id: "L20-1"
# }
# vehicle {
#   label: "3-door"
# }
#
# trip {
#   trip_id: "1771491"
#   schedule_relationship: SCHEDULED
# }
# stop_time_update {
#   arrival {
#     delay: 186
#     time: 1765931779
#     uncertainty: 30
#   }
#   departure {
#     delay: 186
#     time: 1765931802
#     uncertainty: 30
#   }
#   stop_id: "M10-2"
# }
# stop_time_update {
#   arrival {
#     delay: 136
#     time: 1765932074
#     uncertainty: 30
#   }
#   departure {
#     delay: 136
#     time: 1765932094
#     uncertainty: 30
#   }
#   stop_id: "A10-1"
# }
# stop_time_update {
#   arrival {
#     delay: 107
#     time: 1765932298
#     uncertainty: 30
#   }
#   departure {
#     delay: 107
#     time: 1765932316
#     uncertainty: 30
#   }
#   stop_id: "A20-1"
# }
# stop_time_update {
#   arrival {
#     delay: 101
#     time: 1765932484
#     uncertainty: 30
#   }
#   departure {
#     delay: 101
#     time: 1765932502
#     uncertainty: 30
#   }
#   stop_id: "A30-1"
# }
# stop_time_update {
#   arrival {
#     delay: 95
#     time: 1765932723
#     uncertainty: 30
#   }
#   departure {
#     delay: 95
#     time: 1765932741
#     uncertainty: 30
#   }
#   stop_id: "A40-1"
# }
# stop_time_update {
#   arrival {
#     delay: 64
#     time: 1765932919
#     uncertainty: 30
#   }
#   departure {
#     delay: 64
#     time: 1765932955
#     uncertainty: 30
#   }
#   stop_id: "A50-1"
# }
# stop_time_update {
#   arrival {
#     delay: 63
#     time: 1765933199
#     uncertainty: 30
#   }
#   departure {
#     delay: 63
#     time: 1765933217
#     uncertainty: 30
#   }
#   stop_id: "L10-1"
# }
# stop_time_update {
#   arrival {
#     delay: 64
#     time: 1765933778
#     uncertainty: 30
#   }
#   departure {
#     delay: 64
#     time: 1765933796
#     uncertainty: 30
#   }
#   stop_id: "L20-1"
# }
# vehicle {
#   label: "3-door"
# }
#
# trip {
#   trip_id: "1771457"
#   schedule_relationship: SCHEDULED
# }
# stop_time_update {
#   arrival {
#     delay: 107
#     time: 1765931615
#     uncertainty: 30
#   }
#   departure {
#     delay: 107
#     time: 1765931633
#     uncertainty: 30
#   }
#   stop_id: "M80-2"
# }
# stop_time_update {
#   arrival {
#     delay: 84
#     time: 1765931730
#     uncertainty: 30
#   }
#   departure {
#     delay: 84
#     time: 1765931748
#     uncertainty: 30
#   }
#   stop_id: "M70-2"
# }
# stop_time_update {
#   arrival {
#     delay: 83
#     time: 1765931891
#     uncertainty: 30
#   }
#   departure {
#     delay: 83
#     time: 1765931909
#     uncertainty: 30
#   }
#   stop_id: "M60-2"
# }
# stop_time_update {
#   arrival {
#     delay: 76
#     time: 1765932005
#     uncertainty: 30
#   }
#   departure {
#     delay: 76
#     time: 1765932027
#     uncertainty: 30
#   }
#   stop_id: "M50-2"
# }
# stop_time_update {
#   arrival {
#     delay: 69
#     time: 1765932142
#     uncertainty: 30
#   }
#   departure {
#     delay: 69
#     time: 1765932166
#     uncertainty: 30
#   }
#   stop_id: "M40-2"
# }
# stop_time_update {
#   arrival {
#     delay: 66
#     time: 1765932235
#     uncertainty: 30
#   }
#   departure {
#     delay: 66
#     time: 1765932265
#     uncertainty: 30
#   }
#   stop_id: "M30-2"
# }
# stop_time_update {
#   arrival {
#     delay: 62
#     time: 1765932326
#     uncertainty: 30
#   }
#   departure {
#     delay: 62
#     time: 1765932354
#     uncertainty: 30
#   }
#   stop_id: "M20-2"
# }
# stop_time_update {
#   arrival {
#     delay: 56
#     time: 1765932416
#     uncertainty: 30
#   }
#   departure {
#     delay: 56
#     time: 1765932445
#     uncertainty: 30
#   }
#   stop_id: "M16-2"
# }
# stop_time_update {
#   arrival {
#     delay: 37
#     time: 1765932829
#     uncertainty: 30
#   }
#   departure {
#     delay: 37
#     time: 1765932852
#     uncertainty: 30
#   }
#   stop_id: "M10-2"
# }
# stop_time_update {
#   arrival {
#     delay: 0
#     time: 1765933139
#     uncertainty: 30
#   }
#   departure {
#     delay: 0
#     time: 1765933159
#     uncertainty: 30
#   }
#   stop_id: "A10-1"
# }
# stop_time_update {
#   arrival {
#     delay: 0
#     time: 1765933392
#     uncertainty: 30
#   }
#   departure {
#     delay: 0
#     time: 1765933410
#     uncertainty: 30
#   }
#   stop_id: "A20-1"
# }
# stop_time_update {
#   arrival {
#     delay: 0
#     time: 1765933584
#     uncertainty: 30
#   }
#   departure {
#     delay: 0
#     time: 1765933602
#     uncertainty: 30
#   }
#   stop_id: "A30-1"
# }
# stop_time_update {
#   arrival {
#     delay: 0
#     time: 1765933829
#     uncertainty: 30
#   }
#   departure {
#     delay: 0
#     time: 1765933847
#     uncertainty: 30
#   }
#   stop_id: "A40-1"
# }
# stop_time_update {
#   arrival {
#     delay: 0
#     time: 1765934055
#     uncertainty: 30
#   }
#   departure {
#     delay: 0
#     time: 1765934091
#     uncertainty: 30
#   }
#   stop_id: "A50-1"
# }
# stop_time_update {
#   arrival {
#     delay: 0
#     time: 1765934337
#     uncertainty: 30
#   }
#   departure {
#     delay: 0
#     time: 1765934355
#     uncertainty: 30
#   }
#   stop_id: "L10-1"
# }
# stop_time_update {
#   arrival {
#     delay: 0
#     time: 1765934915
#     uncertainty: 30
#   }
#   departure {
#     delay: 0
#     time: 1765934933
#     uncertainty: 30
#   }
#   stop_id: "L20-1"
# }
# vehicle {
#   label: "3-door"
# }
#
# trip {
#   trip_id: "666"
#   schedule_relationship: SCHEDULED
# }
# stop_time_update {
#   arrival {
#     delay: 0
#     time: 1765932491
#     uncertainty: 30
#   }
#   departure {
#     delay: 0
#     time: 1765932521
#     uncertainty: 30
#   }
#   stop_id: "E20-1"
# }
# vehicle {
#   label: "2-door"
# }
#
# trip {
#   trip_id: "668"
#   schedule_relationship: SCHEDULED
# }
# stop_time_update {
#   arrival {
#     delay: 0
#     time: 1765933691
#     uncertainty: 30
#   }
#   departure {
#     delay: 0
#     time: 1765933721
#     uncertainty: 30
#   }
#   stop_id: "E20-1"
# }
# vehicle {
#   label: "2-door"
# }
#
# trip {
#   trip_id: "670"
#   schedule_relationship: SCHEDULED
# }
# stop_time_update {
#   arrival {
#     delay: 0
#     time: 1765934891
#     uncertainty: 30
#   }
#   departure {
#     delay: 0
#     time: 1765934921
#     uncertainty: 30
#   }
#   stop_id: "E20-1"
# }
# vehicle {
#   label: "2-door"
# }
#
# trip {
#   trip_id: "671"
#   schedule_relationship: SCHEDULED
# }
# stop_time_update {
#   arrival {
#     delay: 0
#     time: 1765931641
#     uncertainty: 30
#   }
#   departure {
#     delay: 0
#     time: 1765931671
#     uncertainty: 30
#   }
#   stop_id: "E20-2"
# }
# vehicle {
#   label: "2-door"
# }
#
# trip {
#   trip_id: "672"
#   schedule_relationship: SCHEDULED
# }
# stop_time_update {
#   arrival {
#     delay: 0
#     time: 1765936091
#     uncertainty: 30
#   }
#   departure {
#     delay: 0
#     time: 1765936121
#     uncertainty: 30
#   }
#   stop_id: "E20-1"
# }
# vehicle {
#   label: "2-door"
# }
#
# trip {
#   trip_id: "673"
#   schedule_relationship: SCHEDULED
# }
# stop_time_update {
#   arrival {
#     delay: 0
#     time: 1765932228
#     uncertainty: 30
#   }
#   departure {
#     delay: 0
#     time: 1765932528
#     uncertainty: 30
#   }
#   stop_id: "E30-2"
# }
# stop_time_update {
#   arrival {
#     delay: 0
#     time: 1765932972
#     uncertainty: 30
#   }
#   departure {
#     delay: 0
#     time: 1765933002
#     uncertainty: 30
#   }
#   stop_id: "E20-2"
# }
# vehicle {
#   label: "2-door"
# }
#
# trip {
#   trip_id: "675"
#   schedule_relationship: SCHEDULED
# }
# stop_time_update {
#   arrival {
#     delay: 0
#     time: 1765933428
#     uncertainty: 30
#   }
#   departure {
#     delay: 0
#     time: 1765933728
#     uncertainty: 30
#   }
#   stop_id: "E30-2"
# }
# stop_time_update {
#   arrival {
#     delay: 0
#     time: 1765934172
#     uncertainty: 30
#   }
#   departure {
#     delay: 0
#     time: 1765934202
#     uncertainty: 30
#   }
#   stop_id: "E20-2"
# }
# vehicle {
#   label: "2-door"
# }
#
# trip {
#   trip_id: "677"
#   schedule_relationship: SCHEDULED
# }
# stop_time_update {
#   arrival {
#     delay: 0
#     time: 1765934628
#     uncertainty: 30
#   }
#   departure {
#     delay: 0
#     time: 1765934928
#     uncertainty: 30
#   }
#   stop_id: "E30-2"
# }
# stop_time_update {
#   arrival {
#     delay: 0
#     time: 1765935372
#     uncertainty: 30
#   }
#   departure {
#     delay: 0
#     time: 1765935402
#     uncertainty: 30
#   }
#   stop_id: "E20-2"
# }
# vehicle {
#   label: "2-door"
# }
#
# trip {
#   trip_id: "679"
#   schedule_relationship: SCHEDULED
# }
# stop_time_update {
#   arrival {
#     delay: 0
#     time: 1765935828
#     uncertainty: 30
#   }
#   departure {
#     delay: 0
#     time: 1765936128
#     uncertainty: 30
#   }
#   stop_id: "E30-2"
# }
# stop_time_update {
#   arrival {
#     delay: 0
#     time: 1765936572
#     uncertainty: 30
#   }
#   departure {
#     delay: 0
#     time: 1765936602
#     uncertainty: 30
#   }
#   stop_id: "E20-2"
# }
# vehicle {
#   label: "2-door"
# }
#
# trip {
#   trip_id: "907161210"
#   schedule_relationship: ADDED
# }
# stop_time_update {
#   arrival {
#     delay: 79
#     time: 1765931573
#     uncertainty: 30
#   }
#   departure {
#     delay: 79
#     time: 1765931583
#     uncertainty: 30
#   }
#   stop_id: "A10-2"
# }
# stop_time_update {
#   arrival {
#     delay: 64
#     time: 1765931868
#     uncertainty: 30
#   }
#   departure {
#     delay: 64
#     time: 1765931878
#     uncertainty: 30
#   }
#   stop_id: "M10-1"
# }
# stop_time_update {
#   arrival {
#     delay: 34
#     time: 1765932232
#     uncertainty: 30
#   }
#   departure {
#     delay: 34
#     time: 1765932242
#     uncertainty: 30
#   }
#   stop_id: "M16-1"
# }
# stop_time_update {
#   arrival {
#     delay: 32
#     time: 1765932306
#     uncertainty: 30
#   }
#   departure {
#     delay: 32
#     time: 1765932316
#     uncertainty: 30
#   }
#   stop_id: "M20-1"
# }
# stop_time_update {
#   arrival {
#     delay: 33
#     time: 1765932389
#     uncertainty: 30
#   }
#   departure {
#     delay: 33
#     time: 1765932399
#     uncertainty: 30
#   }
#   stop_id: "M30-1"
# }
# stop_time_update {
#   arrival {
#     delay: 34
#     time: 1765932472
#     uncertainty: 30
#   }
#   departure {
#     delay: 34
#     time: 1765932482
#     uncertainty: 30
#   }
#   stop_id: "M40-1"
# }
# stop_time_update {
#   arrival {
#     delay: 33
#     time: 1765932601
#     uncertainty: 30
#   }
#   departure {
#     delay: 33
#     time: 1765932611
#     uncertainty: 30
#   }
#   stop_id: "M50-1"
# }
# stop_time_update {
#   arrival {
#     delay: 31
#     time: 1765932711
#     uncertainty: 30
#   }
#   departure {
#     delay: 31
#     time: 1765932721
#     uncertainty: 30
#   }
#   stop_id: "M60-1"
# }
# stop_time_update {
#   arrival {
#     delay: 31
#     time: 1765932871
#     uncertainty: 30
#   }
#   departure {
#     delay: 31
#     time: 1765932881
#     uncertainty: 30
#   }
#   stop_id: "M70-1"
# }
# stop_time_update {
#   arrival {
#     delay: 0
#     time: 1765932970
#     uncertainty: 30
#   }
#   departure {
#     delay: 0
#     time: 1765932980
#     uncertainty: 30
#   }
#   stop_id: "M80-1"
# }
# vehicle {
#   label: "3-door"
# }
#
# trip {
#   trip_id: "909162210"
#   schedule_relationship: ADDED
# }
# stop_time_update {
#   arrival {
#     delay: 404
#     time: 1765931624
#     uncertainty: 30
#   }
#   departure {
#     delay: 404
#     time: 1765931634
#     uncertainty: 30
#   }
#   stop_id: "A50-2"
# }
# stop_time_update {
#   arrival {
#     delay: 379
#     time: 1765931813
#     uncertainty: 30
#   }
#   departure {
#     delay: 379
#     time: 1765931823
#     uncertainty: 30
#   }
#   stop_id: "A40-2"
# }
# stop_time_update {
#   arrival {
#     delay: 365
#     time: 1765932037
#     uncertainty: 30
#   }
#   departure {
#     delay: 365
#     time: 1765932047
#     uncertainty: 30
#   }
#   stop_id: "A30-2"
# }
# stop_time_update {
#   arrival {
#     delay: 355
#     time: 1765932211
#     uncertainty: 30
#   }
#   departure {
#     delay: 355
#     time: 1765932221
#     uncertainty: 30
#   }
#   stop_id: "A20-2"
# }
# stop_time_update {
#   arrival {
#     delay: 342
#     time: 1765932448
#     uncertainty: 30
#   }
#   departure {
#     delay: 342
#     time: 1765932458
#     uncertainty: 30
#   }
#   stop_id: "A10-2"
# }
# stop_time_update {
#   arrival {
#     delay: 334
#     time: 1765932750
#     uncertainty: 30
#   }
#   departure {
#     delay: 334
#     time: 1765932760
#     uncertainty: 30
#   }
#   stop_id: "M10-1"
# }
# stop_time_update {
#   arrival {
#     delay: 323
#     time: 1765933133
#     uncertainty: 30
#   }
#   departure {
#     delay: 323
#     time: 1765933143
#     uncertainty: 30
#   }
#   stop_id: "M16-1"
# }
# stop_time_update {
#   arrival {
#     delay: 319
#     time: 1765933205
#     uncertainty: 30
#   }
#   departure {
#     delay: 319
#     time: 1765933215
#     uncertainty: 30
#   }
#   stop_id: "M20-1"
# }
# stop_time_update {
#   arrival {
#     delay: 310
#     time: 1765933278
#     uncertainty: 30
#   }
#   departure {
#     delay: 310
#     time: 1765933288
#     uncertainty: 30
#   }
#   stop_id: "M30-1"
# }
# stop_time_update {
#   arrival {
#     delay: 306
#     time: 1765933356
#     uncertainty: 30
#   }
#   departure {
#     delay: 306
#     time: 1765933366
#     uncertainty: 30
#   }
#   stop_id: "M40-1"
# }
# stop_time_update {
#   arrival {
#     delay: 300
#     time: 1765933480
#     uncertainty: 30
#   }
#   departure {
#     delay: 300
#     time: 1765933490
#     uncertainty: 30
#   }
#   stop_id: "M50-1"
# }
# stop_time_update {
#   arrival {
#     delay: 298
#     time: 1765933590
#     uncertainty: 30
#   }
#   departure {
#     delay: 298
#     time: 1765933600
#     uncertainty: 30
#   }
#   stop_id: "M60-1"
# }
# stop_time_update {
#   arrival {
#     delay: 296
#     time: 1765933748
#     uncertainty: 30
#   }
#   departure {
#     delay: 296
#     time: 1765933758
#     uncertainty: 30
#   }
#   stop_id: "M70-1"
# }
# stop_time_update {
#   arrival {
#     delay: 290
#     time: 1765933872
#     uncertainty: 30
#   }
#   departure {
#     delay: 290
#     time: 1765933882
#     uncertainty: 30
#   }
#   stop_id: "M80-1"
# }
# vehicle {
#   label: "3-door"
# }

# %%
datetime.fromtimestamp
# Out:
# <function datetime.fromtimestamp>

# %%
datetime.fromtimestamp(entity.trip_update.stop_time_update[0].arrival.time)
# Out:
# datetime.datetime(2025, 12, 16, 16, 33, 44)
